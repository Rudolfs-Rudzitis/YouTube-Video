# %% [markdown]
# # Introduction

# %% [markdown]
# *I will perform data cleansing, wrangling and analyzing on **4** datasets, **3** of them contains data about YouTube Trending videos in 3 different parts of the world - USA, Canada and Great Britain. The **4th** dataset contains category types the videos is accosiated with.*

# %% [markdown]
# ### Tools Used

# %% [markdown]
# *This analysis was performed using Python and a group of Python libraries including Pandas, Matplotlib, Numpy and more. The analysis were performed in a Jupyter Notebook.*

# %% [markdown]
# ### The Goal

# %% [markdown]
# *The goal of the analysis is to find answers to various questions and patterns by exploring the data.*

# %% [markdown]
# ### Questions that the business team wants to be answered:

# %% [markdown]
# *1) Are there any clear differences between trending videos depending on the region?*

# %% [markdown]
# *2) Which video remained the most on the trending videos list?*

# %% [markdown]
# *3) Which video category has the largest number of trending videos? Does the category give any advantage in order to become trending?*

# %% [markdown]
# *4) How are views, likes and dislikes, title length, and other attributes correlated with (relate to) each other? Are they connected in any way?*

# %% [markdown]
# *5) If Nordigen would upload a video, what words in the title (or description) or tags would you recommend to use? (In hopes to make the video trending).*

# %% [markdown]
# ### Questions that I am interested in:

# %% [markdown]
# *1) Which videos had the most views in each region (USA, Canada, GB)?*

# %% [markdown]
# *2) How much of trending videos had their comments and ratings option turned off?*

# %% [markdown]
# #### Importing required Python libraries for analysis.

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
from matplotlib import ticker
import seaborn as sns
from collections import Counter

# %% [markdown]
# ##### Reading 1st dataset "US videos" and getting familiar with it.

# %%
usa = pd.read_csv('USvideos.csv', sep=';')
usa.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#                publish_time      views     likes  dislikes  comment_count  \
# 0  2017-11-13T17:13:01.000Z   748374.0   57527.0    2966.0        15954.0
# 1  2017-11-13T07:30:00.000Z  2418783.0   97185.0    6146.0        12703.0
# 2  2017-11-12T19:05:24.000Z  3191434.0  146033.0    5339.0         8181.0
# 3  2017-11-13T11:00:04.000Z   343168.0   10172.0     666.0         2146.0
# 4  2017-11-12T18:01:41.000Z  2095731.0  132235.0    1989.0        17518.0
#
#                                    thumbnail_link comments_disabled  \
# 0  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg             False
# 1  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg             False
# 2  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg             False
# 3  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg             False
# 4  https://i.ytimg.com/vi/d380meD0W0M/default.jpg             False
#
#   ratings_disabled video_error_or_removed  \
# 0            False                  False
# 1            False                  False
# 2            False                  False
# 3            False                  False
# 4            False                  False
#
#                                          description country  \
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...      US
# 1  One year after the presidential election, John...      US
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...      US
# 3  Today we find out if Link is a Nickelback amat...      US
# 4  I know it's been a while since we did this sho...      US
#
#                                                 tags  category_id
# 0                                 ,'shantell martin'        804.0
# 1  ,'last week tonight trump presidency','last we...        806.0
# 2  ,'racist superman','rudy','mancuso','king','ba...        805.0
# 3  ,'rhett and link','gmm','good mythical morning...        806.0
# 4  ,'ryan','higa','higatv','nigahiga','i dare you...        806.0

# %% [markdown]
# *The next table shows what kind of data describes each video in dataset:*

# %%
usa.head(1).transpose()
# Out:
#                                                                         0
# video_id                                                      2kyS6SvSYSE
# trending_date                                                    17.14.11
# title                                  WE WANT TO TALK ABOUT OUR MARRIAGE
# channel_title                                                CaseyNeistat
# publish_time                                          2017-11-13 17:13:01
# views                                                              748374
# likes                                                               57527
# dislikes                                                             2966
# comment_count                                                       15954
# thumbnail_link             https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             SHANTELL'S CHANNEL - https://www.youtube.com/s...
# country                                                                US
# tags                                                   ,'shantell martin'
# category_id                                                           804

# %% [markdown]
# ##### Shape of our Dataset

# %%
usa.shape
# Out:
# (46978, 17)

# %% [markdown]
# *Dataset consist of **46 978** rows and **17** columns.*

# %% [markdown]
# ##### The names of all columns in this dataset

# %%
usa.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'publish_time',
#        'views', 'likes', 'dislikes', 'comment_count', 'thumbnail_link',
#        'comments_disabled', 'ratings_disabled', 'video_error_or_removed',
#        'description', 'country', 'tags', 'category_id'],
#       dtype='object')

# %% [markdown]
# ##### Unique videos in a dataset

# %%
count_of_unique_videos_usa = usa['video_id'].unique().shape[0]
count_of_unique_videos_usa
# Out:
# 6828

# %% [markdown]
# *USA dateset contains **6828** unique videos*

# %% [markdown]
# ## Column Data types (USA)

# %%
usa.dtypes
# Out:
# video_id                   object
# trending_date              object
# title                      object
# channel_title              object
# publish_time               object
# views                     float64
# likes                     float64
# dislikes                  float64
# comment_count             float64
# thumbnail_link             object
# comments_disabled          object
# ratings_disabled           object
# video_error_or_removed     object
# description                object
# country                    object
# tags                       object
# category_id               float64
# dtype: object

# %% [markdown]
# *Columns like 'views', 'likes', 'dislikes' and 'comment_count' only need INT data type, instead of FLOAT in order to save memory, which is important if working with huge datasets.*

# %% [markdown]
# *We also want to change Data Types for **'trending_date'** and **'publish_time'**, so we can make analysis with them*

# %%
column_datatypes_to_change = ['views', 'likes', 'dislikes', 'comment_count']
for column in column_datatypes_to_change:
    usa[column] = usa[column].astype(int)

# %%
usa['trending_date'] = pd.to_datetime(usa['trending_date'],errors='coerce', format='%y.%d.%m')

# %%
usa['publish_time'] = pd.to_datetime(usa['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# %%
usa.dtypes
# Out:
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# publish_time              datetime64[ns]
# views                              int32
# likes                              int32
# dislikes                           int32
# comment_count                      int32
# thumbnail_link                    object
# comments_disabled                 object
# ratings_disabled                  object
# video_error_or_removed            object
# description                       object
# country                           object
# tags                              object
# category_id                      float64
# dtype: object

# %% [markdown]
# ## Missing data (USA)

# %% [markdown]
# *First of all, I want to know how much missing date (Null values) is in each of the columns.*

# %%
for i in usa.columns:
    null_rate = usa[i].isna().sum()/len(usa)*100
    if null_rate >= 0:
        print("Column '{}' null rate: {}%".format(i,round(null_rate,2)))
# Out:
# Column 'video_id' null rate: 0.0%
# Column 'trending_date' null rate: 12.93%
# Column 'title' null rate: 10.48%
# Column 'channel_title' null rate: 10.85%
# Column 'publish_time' null rate: 12.93%
# Column 'views' null rate: 0.0%
# Column 'likes' null rate: 0.0%
# Column 'dislikes' null rate: 0.0%
# Column 'comment_count' null rate: 0.0%
# Column 'thumbnail_link' null rate: 12.93%
# Column 'comments_disabled' null rate: 12.93%
# Column 'ratings_disabled' null rate: 12.93%
# Column 'video_error_or_removed' null rate: 12.93%
# Column 'description' null rate: 14.15%
# Column 'country' null rate: 15.39%
# Column 'tags' null rate: 15.39%
# Column 'category_id' null rate: 19.36%

# %% [markdown]
# *Column 'category_id' has the most missing values - almost the **fifth part** is missing.*

# %%
usa.isnull().sum()
# Out:
# video_id                     0
# trending_date             4923
# title                     4923
# channel_title             5097
# publish_time              6076
# views                     6076
# likes                     6076
# dislikes                  6076
# comment_count             6076
# thumbnail_link            6076
# comments_disabled         6076
# ratings_disabled          6076
# video_error_or_removed    6076
# description               6646
# country                   7229
# tags                      7229
# category_id               9095
# dtype: int64

# %% [markdown]
# *We can see that all columns (except **'video_id'**) contains couple thousands of NULL values. There are no 1 right way to deal with them. In order to make the best desicion it's important to understand well the dataset we are working with.*

# %% [markdown]
# *Since I want to do analysis on columns **Views**, **Likes,** **Dislikes** and **Comment_count**, we have to get rid of missing values in these columns. We could replace missing values with average values in each column, but this time I think we can replace NaN values with 0 as well.*

# %%
usa['views'] = usa['views'].fillna(0)

# %%
usa['likes'] = usa['likes'].fillna(0)

# %%
usa['dislikes'] = usa['dislikes'].fillna(0)

# %%
usa['comment_count'] = usa['comment_count'].fillna(0)

# %%
usa.isnull().sum()
# Out:
# video_id                     0
# trending_date             4923
# title                     4923
# channel_title             5097
# publish_time              6076
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link            6076
# comments_disabled         6076
# ratings_disabled          6076
# video_error_or_removed    6076
# description               6646
# country                   7229
# tags                      7229
# category_id               9095
# dtype: int64

# %% [markdown]
# *Now neither of the mentioned columns has NULL values.*

# %% [markdown]
# ### Disabled Comments, Ratings & Errors

# %% [markdown]
# *Since we got column named **video_error_or_removed** we can learn how many trending videos had an error or they were removed*

# %%
usa["video_error_or_removed"].value_counts()
# Out:
# False    40879
# True        23
# Name: video_error_or_removed, dtype: int64

# %% [markdown]
# *Out of videos that appeared on trending list (40 879) only **23** videos had errors or they were removed.*

# %% [markdown]
# We can also find out how many videos had their comments disabled since we have a column called **comments_disabled**.

# %%
usa["comments_disabled"].value_counts()
# Out:
# False    40269
# True       633
# Name: comments_disabled, dtype: int64

# %% [markdown]
# *Only **633** videos had their comments disabled which is **1,5%** of all videos (as seen in code below).*

# %%
usa["comments_disabled"].value_counts(normalize=True)
# Out:
# False    0.984524
# True     0.015476
# Name: comments_disabled, dtype: float64

# %% [markdown]
# *Similar situation with videos that had their ratings disabled (use **ratings_disabled** column)*

# %%
usa["ratings_disabled"].value_counts()
# Out:
# False    40733
# True       169
# Name: ratings_disabled, dtype: int64

# %% [markdown]
# *Again, only a small portion **(169)** of all videos had their ratings disabled.*

# %% [markdown]
# #### Videos that remained the most on trending video list (USA)

# %%
usa['title'].value_counts().head(20)
# Out:
# WE MADE OUR MOM CRY...HER DREAM CAME TRUE!                                      30
# YoungBoy Never Broke Again Goes Sneaker Shopping With Complex                   29
# Rooster Teeth Animated Adventures - Millie So Serious                           29
# Charlie Puth - BOY [Official Audio]                                             29
# Sam Smith - Pray (Official Video) ft. Logic                                     29
# The ULTIMATE $30,000 Gaming PC Setup                                            29
# Why I'm So Scared (being myself and crying too much)                            29
# Mission: Impossible - Fallout (2018) - Official Trailer - Paramount Pictures    29
# Rita Ora - Girls ft. Cardi B, Bebe Rexha & Charli XCX (Official Lyric Video)    28
# 周杰倫 Jay Chou【不愛我就拉倒 If You Don't Love Me, It's Fine】Official MV                 28
# John Mayer - New Light                                                          28
# FORTNITE The Movie (Official Fake Trailer)                                      28
# Bohemian Rhapsody | Teaser Trailer [HD] | 20th Century FOX                      28
# Getting some air, Atlas?                                                        28
# The Deadliest Being on Planet Earth – The Bacteriophage                         28
# Selena Gomez - Back To You (Lyric Video)                                        28
# Cobra Kai Season 2                                                              28
# BLACKkKLANSMAN - Official Trailer [HD] - In Theaters August 10                  27
# Why You Should Wake Up at 4:30 AM Every Day, According To A Navy SEAL           27
# Destination Wedding Trailer #1 (2018) | Movieclips Trailers                     27
# Name: title, dtype: int64

# %% [markdown]
# *Table above shows that in the USA dataset video that remained the most on trending video list is called **"WE MADE OUR MOM CRY...HER DREAM CAME TRUE!",** it appeared on the list **30** times.*

# %% [markdown]
# ### Top Categories (USA)

# %%
usa['category_id'].value_counts().head(120)
# Out:
# 806.0    9454
# 600.0    6454
# 805.0    3451
# 804.0    3166
# 102.0    2448
#          ...
# 544.0       2
# 542.0       2
# 418.0       1
# 448.0       1
# 497.0       1
# Name: category_id, Length: 116, dtype: int64

# %% [markdown]
# *There are several options to determine the most popular categories. This time I will use Loc function to categorize videos in to categories based on file **categories.csv**.*

# %%
categories = pd.read_csv('categories.csv', sep=';')
categories.head()
# Out:
#    category_id  category_id_lvl_0  category_id_lvl_1  category_id_lvl_2  \
# 0          101                100              101.0                NaN
# 1          102                100              102.0                NaN
# 2          201                200              201.0                NaN
# 3          202                200              202.0                NaN
# 4          203                200              203.0                NaN
#
#     category_title_lvl_0   category_title_lvl_1 category_title_lvl_2
# 0  Politics & Nonprofits  Nonprofits & Activism                  NaN
# 1  Politics & Nonprofits        News & Politics                  NaN
# 2                 Cinema       Film & Animation                  NaN
# 3                 Cinema               Trailers                  NaN
# 4                 Cinema            Full Movies                  NaN

# %%
# Based on data that is found in categories.csv we can found out the distribution of videos by Categories

politics = usa.loc[(usa.category_id >= 100) & (usa.category_id <= 102)].count()[0]
cinema = usa.loc[(usa.category_id >= 200) & (usa.category_id <= 204)].count()[0]
education = usa.loc[(usa.category_id >= 300) & (usa.category_id <= 302)].count()[0]
diy_and_beauty = usa.loc[(usa.category_id >= 400) & (usa.category_id <= 497)].count()[0]
travel_and_events = usa.loc[(usa.category_id >= 500) & (usa.category_id <= 551)].count()[0]
music = usa.loc[(usa.category_id >= 600) & (usa.category_id <= 600)].count()[0]
animals = usa.loc[(usa.category_id >= 700) & (usa.category_id <= 700)].count()[0]
entertainment = usa.loc[(usa.category_id >= 800) & (usa.category_id <= 806)].count()[0]

categories = [politics, cinema, education, diy_and_beauty, travel_and_events, music, animals, entertainment]
explode = [0,.4,0,.25,.25,0,.5,0]
colors = ['magenta', 'cyan', 'pink', 'salmon', 'khaki', 'lightblue', 'lightgreen', 'orange']
labels = ['Politics', 'Cinema', 'Education', 'DIY&Beauty', 'Travel&Events', 'Music', 'Animals', 'Entertainment']

#plt.title('Distribution of videos by Categories!')

plt.pie(categories, labels=labels, radius=3, colors=colors, autopct='%.2f %%', pctdistance=0.8, explode=explode)
plt.show()

# %% [markdown]
# *In the Pie Chart above we see that when looking at USA dateset Entertainment category contains the largest number of trending videos among other categories (**50,85%** or ~ 20 000 videos), followed by Music category (**17,04%** or ~ 6 500 videos), followed by Education category (**10,51%** or 4 000 videos), and so on.*

# %% [markdown]
# ## Views of the videos (USA)

# %% [markdown]
# #### A trending video with the fewest views (excluding those with 0 views)

# %%
usa[usa['views'] == usa['views'].min()].transpose()
# Out:
#                                                                     16285
# video_id                                                      y6KYFcta4SE
# trending_date                                                    18.26.01
# title                    1 dead, others injured after Ky. school shooting
# channel_title                                                       Newsy
# publish_time                                     2018-01-23T15:30:01.000Z
# views                                                                 549
# likes                                                                   9
# dislikes                                                                0
# comment_count                                                           5
# thumbnail_link             https://i.ytimg.com/vi/y6KYFcta4SE/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             Kentucky Gov. Matt Bevin confirmed there was a...
# country                                                                US
# tags                    ,'shooting','kentucky','breaking news','u.s. n...
# category_id                                                           102

# %% [markdown]
# *Video with the **LEAST** views is called "1 dead, others injured after Ky. school shooting" from channel "Newsy" which had accumulated **549** views.*

# %% [markdown]
# *TOP 5 trending videos with the **LEAST** Views - excluding those with 0 views*

# %%
unique_videos_usa_least_views = (usa[usa['views'] > 0].sort_values(by='views', ascending=True)).drop_duplicates(subset=['video_id']).head(5)
unique_videos_usa_least_views
# Out:
#           video_id trending_date  \
# 16285  y6KYFcta4SE      18.26.01
# 16499  dQMZLXaa1L8      18.27.01
# 687    -JVITToppE0      17.16.11
# 14504  zeQaJGkFyqQ      18.18.01
# 179    qg0GdM60syI      17.14.11
#
#                                                   title     channel_title  \
# 16285  1 dead, others injured after Ky. school shooting             Newsy
# 16499                                     Artwork Forge  Palo Alto Online
# 687       Coach Taggart Monday Presser Ahead of Arizona     GoDucksdotcom
# 14504    Raw: 3 South Carolina Deputies, 1 Officer Shot  Associated Press
# 179              Huffy Metaloid Bicycle Commercial 1997   90s Commercials
#
#              publish_time  views  likes  dislikes  comment_count  \
# 16285 2018-01-23 15:30:01    549      9         0              5
# 16499 2018-01-10 23:53:56    658      1         0              0
# 687   2017-11-13 20:41:45    687     10         2              5
# 14504 2018-01-16 12:16:44    748      9         0              0
# 179   2017-03-31 21:46:53    773      2         0              0
#
#                                        thumbnail_link comments_disabled  \
# 16285  https://i.ytimg.com/vi/y6KYFcta4SE/default.jpg             False
# 16499  https://i.ytimg.com/vi/dQMZLXaa1L8/default.jpg             False
# 687    https://i.ytimg.com/vi/-JVITToppE0/default.jpg             False
# 14504  https://i.ytimg.com/vi/zeQaJGkFyqQ/default.jpg              True
# 179    https://i.ytimg.com/vi/qg0GdM60syI/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 16285            False                  False
# 16499            False                  False
# 687              False                  False
# 14504            False                  False
# 179              False                  False
#
#                                              description country  \
# 16285  Kentucky Gov. Matt Bevin confirmed there was a...      US
# 16499  Artwork Forge II - an art installation created...      US
# 687    Coach Taggart addresses the media ahead of the...      US
# 14504  Three deputies and one police officer were sho...     NaN
# 179                            Anyone have one of those?      US
#
#                                                     tags  category_id
# 16285  ,'shooting','kentucky','breaking news','u.s. n...        102.0
# 16499                                          ,'[none]'        802.0
# 687    ,'oregon','ducks','college athletics','college...        802.0
# 14504                                                NaN          NaN
# 179                           ,'90s commercials','huffy'        302.0

# %% [markdown]
# #### A trending video with the maximum number of views

# %%
usa[usa['views'] == usa['views'].max()].transpose()
# Out:
#                                                                     44424
# video_id                                                      VYOjWnS4cMY
# trending_date                                                    18.02.06
# title                   Childish Gambino - This Is America (Official V...
# channel_title                                         ChildishGambinoVEVO
# publish_time                                     2018-05-06T04:00:07.000Z
# views                                                         2.25212e+08
# likes                                                         5.02345e+06
# dislikes                                                           343541
# comment_count                                                      517232
# thumbnail_link             https://i.ytimg.com/vi/VYOjWnS4cMY/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             “This is America” by Childish Gambino http://s...
# country                                                                US
# tags                    ,'childish gambino','rap','this is america','m...
# category_id                                                           600

# %% [markdown]
# *This view dont give us precise number of views for the most popular video, so we can found it with the code below.*

# %%
usa['views'].max()
# Out:
# 225211923

# %% [markdown]
# *Video with the **MOST** views is called "Childish Gambino - This Is America (Official Video)" from channel "ChildsihGambinoVEVO" which had accumulated more than **225 million** views.

# %% [markdown]
# #### TOP 5 videos with the **MOST** Views

# %%
unique_videos_usa_most_views = usa.sort_values(by='views', ascending=False).drop_duplicates(subset=['video_id'])
unique_videos_usa_most_views[['title', 'views']].head(5)
# Out:
#                                                    title      views
# 44424  Childish Gambino - This Is America (Official V...  225211923
# 7180   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  149376127
# 40199               Ariana Grande - No Tears Left To Cry  148689896
# 40393  Becky G, Natti Natasha - Sin Pijama (Official ...  139334502
# 44132                BTS (방탄소년단) 'FAKE LOVE' Official MV  123010920

# %% [markdown]
# ## The most Likes, Comments, Dislikes and Views (USA)

# %% [markdown]
# *I will create a function 'visualize_most' that will take in a column name and it will visualize the videos that have the most counts of likes, comments, dislikes and views.*

# %%
def visualize_most(, column, num=10):
    sorted_df = usa.sort_values(column, ascending=False).iloc[:num]
    
    ax = sorted_df[column].plot.bar()
    
    # customizes the video titles, for asthetic purposes for the bar chart
    labels = []
    for item in sorted_df['title']:
        labels.append(item[:12] + '...')
    ax.set_xticklabels(labels, rotation=45, fontsize=10)
    
    plt.show()

# %% [markdown]
# *Now we can call the 'visualize_most()' function while passing different column names*

# %%
visualize_most(usa, 'views')

# %%
visualize_most(usa, 'comment_count')

# %%
visualize_most(usa, 'dislikes')

# %%
visualize_most(usa, 'likes', num=20)

# %% [markdown]
# ## Most Popular Trending Channels (USA)

# %%
trending_channels = usa.groupby(['channel_title']).size().sort_values(ascending=False).head(11)
sns.barplot(trending_channels.values, trending_channels.index.values, palette = 'viridis')
plt.title('Top 10')
plt.xlabel('Video Count')
plt.show()
#in results I got some mysterious channel '806' that dont exist, so I ignore it
# Out:
# C:\Users\username\Downloads\Programs\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# *We can conclude that in USA sport channels like ESPN, NBA and bunch of TV Shows are trending the most often.*

# %% [markdown]
# ## Most Popular Publishing Day & Time (USA)

# %% [markdown]
# *Since we have a column of published time that contains day of the week, as well as hour in which video was published, we can split this column in 2 additional columns, where column will contain the name of the day and the 2nd column the number of hour.*

# %%
usa['day_published'] = usa['publish_time'].dt.day_name()
usa['hour_published'] = usa['publish_time'].dt.hour

# %% [markdown]
# *Now the dataset got 2 more columns **day_published** and **hour_published**.* And now we can vizualize it in Bar chart.

# %%
ax = usa['day_published'].value_counts().plot(
    kind='bar', figsize=(10,6), rot=0)

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.tight_layout()

# %% [markdown]
# *As seen in table above, the most trending videos was published in working days - **Thursday, Tuesday, Wednesday and Friday**, on Monday a slight decrease is observed. But on holidays there are a lot less people on internet, so there is no suprise that these are the days when a lot less videos became viral.*

# %% [markdown]
# #### Most Popular Publishing Hour

# %%
ax = usa['hour_published'].value_counts().sort_index().plot(
    kind='bar', figsize=(14,8), rot=0)

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.tight_layout()

# %% [markdown]
# *We can see that the most trending videos was published in the afternoon, gaining at **4 p.m.,** while the night-time is when you dont want to publish a video if you want it to go viral.*

# %% [markdown]
# ### Correlations (USA)

# %%
columns_needed = ['views', 'likes', 'dislikes', 'comment_count'] # only these columns needed this time
corr_matrix = usa[columns_needed].corr()
corr_matrix
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.851188  0.473872       0.620806
# likes          0.851188  1.000000  0.449005       0.804414
# dislikes       0.473872  0.449005  1.000000       0.700838
# comment_count  0.620806  0.804414  0.700838       1.000000

# %% [markdown]
# *We can take one step further and take search for other correlations by inventing new variables (for example Like&Dislike Ratio, Percentage of Comments and Percentage of Reaction)*

# %%
usa['like_dislike_ratio'] = usa['likes'] / usa['dislikes']
usa['comments_percentage'] = usa['comment_count'] / usa['views']
usa['reaction_percentage'] = (usa['likes'] + usa['dislikes']) / usa['views']

# %%
correlation = usa[['views', 'likes', 'dislikes', 'comment_count', 'like_dislike_ratio', 'comments_percentage', 'reaction_percentage']]
corr = correlation.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# *Matrix above shows that there are several moderate correlations. What I can see is that one of the most noticable is **comment count** is positevely related with views, likes and dislikes. That means that people who react with a like or dislike are also more likely leave a comment after watching the video.*

# %% [markdown]
# # ADDITIONAL TASKS:

# %% [markdown]
# # 3rd: The most common words in titles (USA)

# %% [markdown]
# *In order to find it out, first we need to filter out empty cells that otherwise causes error ''float' object has no attribute 'split''.*

# %%
new_usa_df = usa[usa['title'].notnull()]

# %%
title_words = list(new_usa_df['title'].apply(lambda x: x.split()))
title_words = [x for y in title_words for x in y]
Counter(title_words).most_common(30)
# Out:
# [('-', 11452),
#  ('|', 10660),
#  ('The', 5762),
#  ('the', 3949),
#  ('a', 2858),
#  ('to', 2807),
#  ('of', 2561),
#  ('in', 2319),
#  ('and', 2269),
#  ('A', 2122),
#  ('&', 2045),
#  ('I', 1940),
#  ('Video)', 1901),
#  ('Trailer', 1868),
#  ('on', 1744),
#  ('with', 1737),
#  ('How', 1661),
#  ('2018', 1641),
#  ('(Official', 1594),
#  ('Official', 1554),
#  ('To', 1397),
#  ('You', 1254),
#  ('My', 1080),
#  ('for', 1022),
#  ('ft.', 1017),
#  ('In', 943),
#  ('With', 897),
#  ('at', 842),
#  ('Is', 828),
#  ('What', 773)]

# %% [markdown]
# *In USA the most common words in titles is **"The", "the"** and **"a"** - they appeared **5762, 3949** and **2858** times respectively. Only symbols appeared more often than these words: "-" and "|" occured the most: **11452** and **10660** times respectively.*

# %% [markdown]
# # 4th: What are the most common tags in each of the categories?

# %% [markdown]
# *First, check what's the most common tags in the hole dataset*

# %%
new_usa_df_tags = usa[usa['tags'].notnull()]

# %%
popular_tags = list(new_usa_df_tags['tags'].apply(lambda x: x.split()))
popular_tags = [x for y in popular_tags for x in y]
Counter(popular_tags).most_common(30)
# Out:
# [('the', 7477),
#  ('to', 7039),
#  ('of', 5946),
#  ('and', 5928),
#  ('a', 4361),
#  ('in', 3200),
#  ('with', 2380),
#  ('for', 2171),
#  ('on', 2163),
#  ('vs', 1906),
#  ('my', 1882),
#  ('new', 1599),
#  (",'the", 1587),
#  ('you', 1558),
#  ('is', 1556),
#  (",'[none]'", 1535),
#  ('music', 1482),
#  ('it', 1422),
#  ('&', 1417),
#  ('makeup', 1329),
#  ('your', 1245),
#  ('me', 1198),
#  ('voice', 1189),
#  ('make', 1130),
#  ('i', 1123),
#  ('late', 1039),
#  ('perfect', 958),
#  ("youtube','youtube", 869),
#  ('night', 852),
#  ('life', 829)]

# %% [markdown]
# ## 2nd: How many videos in each country that had their Dislikes more than their Likes when first appeared on the trending list (USA)

# %%
usa_without_d = usa.drop_duplicates(subset=['video_id'])

# %% [markdown]
# *If I'm not mistaken, then we dont need to specify which dublicate we want to keep, because by using 'drop_dublicated' it keeps the first dublicate by default*

# %%
usa_without_d['net_dislikes'] = (usa_without_d['dislikes'] - usa_without_d['likes'])
usa_without_d[usa_without_d['net_dislikes'] > 0].sort_values(by='net_dislikes', ascending=False)
# Out:
# <ipython-input-19-664bffc2591c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_without_d['net_dislikes'] = (usa_without_d['dislikes'] - usa_without_d['likes'])
#           video_id trending_date  \
# 8147   LFhT6H6pRWg      17.19.12
# 7200   8d_202l55LU      17.15.12
# 21896  V5cOvyDpWfM      18.21.02
# 45486  GnGPAYvve1A      18.08.06
# 21671  CMA2iF6RuXk      18.20.02
# ...            ...           ...
# 1856   A_mlvG_nRsg      17.21.11
# 13771  yUMalTN2OvM      18.15.01
# 214    u7pV4vxD1bs      17.14.11
# 8066   MXFhiN0tM3s      17.19.12
# 16281  qDI8LnPq3VY      18.26.01
#
#                                                    title  \
# 8147               PSA from Chairman of the FCC Ajit Pai
# 7200            The FCC repeals its net neutrality rules
# 21896  Fergie Performs The U.S. National Anthem / 201...
# 45486                         #ProudToCreate: Pride 2018
# 21671    Fergie's national anthem draws criticism | ESPN
# ...                                                  ...
# 1856   Kelly Oubre Punches John Wall in the Lead duri...
# 13771                                   IoT kit robot #3
# 214    World's first self-driving shuttle crashes on ...
# 8066   Trump delivers remarks regarding his national ...
# 16281                       MTB Skills - Technical Climb
#
#                channel_title              publish_time       views    likes  \
# 8147            Daily Caller  2017-12-13T22:52:57.000Z   1142585.0   9100.0
# 7200         Washington Post  2017-12-14T18:49:06.000Z    985179.0   4870.0
# 21896         MLG Highlights  2018-02-19T01:37:11.000Z  14647590.0  32892.0
# 45486      YouTube Spotlight  2018-06-07T19:08:51.000Z    597669.0  29781.0
# 21671                   ESPN  2018-02-19T12:42:36.000Z   2762839.0  14362.0
# ...                      ...                       ...         ...      ...
# 1856            Rob Andretti  2017-10-28T11:15:14.000Z      2197.0      0.0
# 13771                eba era  2014-03-07T22:39:36.000Z      2910.0      1.0
# 214    KSNV News 3 Las Vegas  2017-11-08T20:16:47.000Z    169511.0     57.0
# 8066         Washington Post  2017-12-18T19:39:39.000Z     24979.0    322.0
# 16281        Geoff Mallinson  2015-04-02T12:41:47.000Z      4681.0      2.0
#
#        dislikes  comment_count  \
# 8147   218841.0        28013.0
# 7200   110707.0        19843.0
# 21896  117128.0        44404.0
# 45486   71617.0        55110.0
# 21671   37877.0        21507.0
# ...         ...            ...
# 1856        2.0            0.0
# 13771       3.0            1.0
# 214        59.0           79.0
# 8066      323.0          441.0
# 16281       3.0            1.0
#
#                                        thumbnail_link comments_disabled  \
# 8147   https://i.ytimg.com/vi/LFhT6H6pRWg/default.jpg             False
# 7200   https://i.ytimg.com/vi/8d_202l55LU/default.jpg             False
# 21896  https://i.ytimg.com/vi/V5cOvyDpWfM/default.jpg             False
# 45486  https://i.ytimg.com/vi/GnGPAYvve1A/default.jpg             False
# 21671  https://i.ytimg.com/vi/CMA2iF6RuXk/default.jpg             False
# ...                                               ...               ...
# 1856   https://i.ytimg.com/vi/A_mlvG_nRsg/default.jpg             False
# 13771  https://i.ytimg.com/vi/yUMalTN2OvM/default.jpg             False
# 214    https://i.ytimg.com/vi/u7pV4vxD1bs/default.jpg             False
# 8066   https://i.ytimg.com/vi/MXFhiN0tM3s/default.jpg             False
# 16281  https://i.ytimg.com/vi/qDI8LnPq3VY/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 8147             False                  False
# 7200             False                  False
# 21896            False                  False
# 45486            False                  False
# 21671            False                  False
# ...                ...                    ...
# 1856             False                  False
# 13771            False                  False
# 214              False                  False
# 8066             False                  False
# 16281            False                  False
#
#                                              description country  \
# 8147   Ajit Pai has been at the heart of the net neut...      US
# 7200   Federal regulators vote to allow Internet prov...      US
# 21896  🏀Fergie Performs The U.S. National Anthem / 20...      US
# 45486  You don't just imagine a better future – you c...      US
# 21671  The Black Eyed Peas singer Fergie provides a u...      US
# ...                                                  ...     ...
# 1856   I'm BACK! \n\n• Will you be apart of the take ...      US
# 13771                                                NaN      US
# 214    Las Vegas is the first city in America to have...      US
# 8066   President Trump delivers remarks regarding his...      US
# 16281  Riding some of the single track at Ourimbah ba...      US
#
#                                                     tags  category_id  \
# 8147   ,'thedc','dc','washington dc','washington','th...        804.0
# 7200   ,'fcc net neutrality','breaking news video','v...        102.0
# 21896  ,'mlg highlights','mlg','basketball','highligh...        802.0
# 45486  ,'#pride','#proudtocreate','#proudtobe','#prou...        806.0
# 21671  ,'espn','espn live','fergie','national','anthe...        802.0
# ...                                                  ...          ...
# 1856                                           ,'[none]'        802.0
# 13771                       ,'aruduino','robot','sensor'        600.0
# 214    ,'technology','self-driving car','las vegas','...        102.0
# 8066   ,'national security','donald trump national se...        102.0
# 16281                                          ,'[none]'        806.0
#
#        net_dislikes
# 8147       209741.0
# 7200       105837.0
# 21896       84236.0
# 45486       41836.0
# 21671       23515.0
# ...             ...
# 1856            2.0
# 13771           2.0
# 214             2.0
# 8066            1.0
# 16281           1.0
#
# [101 rows x 18 columns]

# %% [markdown]
# *The table above shows videos in USA that had their **dislikes** more than their **likes** when they first appeared on the particular region's trending list - in total 101 video.*

# %% [markdown]
# *In next questions we will need to visualize various relationships, so we can create a function, that will do certain activities in order to produce visualizations that will have a better look (imo)*

# %%
def plot_configurations(ax, xlbl='', ylbl='', t='', back_color='#ffffff',
              text_color='#616161', grid_color='#e9e9e9', 
              tick_color='', ticklbl_size=9, lbl_size=11, lang='en'):

    # changing the background color of the plot
    ax.set_facecolor(back_color)
    # modifying the ticks on plot axes
    ax.tick_params(axis='both', labelcolor=text_color, color=back_color)
    if tick_color != '':
        ax.tick_params(axis='both', color=tick_color)
    ax.tick_params(axis='both', which='major', labelsize=ticklbl_size)
    # adding a grid and specifying its color
    ax.grid(True, color=grid_color)
    # making the grid appear behind the graph elements
    ax.set_axisbelow(True)
    # hiding axes
    ax.spines['bottom'].set_color(back_color)
    ax.spines['top'].set_color(back_color) 
    ax.spines['right'].set_color(back_color)
    ax.spines['left'].set_color(back_color)
    # setting the title, x label, and y label of the plot
    if lang == 'ar':
        ax.set_title(get_display(reshaper.reshape(t)), fontweight='bold', family='Amiri',
                     fontsize=14, color=text_color, loc='right', pad=24);
        ax.set_xlabel(get_display(reshaper.reshape(xlbl)), fontweight='bold', family='Amiri',
                      labelpad=16, fontsize=lbl_size, color=text_color, fontstyle='italic');
        ax.set_ylabel(get_display(reshaper.reshape(ylbl)), fontweight='bold', family='Amiri',
                      color=text_color, labelpad=16, fontsize=lbl_size, fontstyle='italic');
    else:
        ax.set_title(t, fontsize=14, color='#616161', loc='left', pad=24, fontweight='bold');
        ax.set_xlabel(xlbl, labelpad=16, fontsize=lbl_size, color='#616161', fontstyle='italic');
        ax.set_ylabel(ylbl, color='#616161', labelpad=16, fontsize=lbl_size, fontstyle='italic');

# %% [markdown]
# # 1st: How many comments a video has when first appearing on the trending list?

# %% [markdown]
# *In the first line below we drop dublicates otherwise the error is kicking out, when we try to plot histogram for values that is NaN.*

# %%
usa_without_d = usa.drop_duplicates(subset=['video_id'])
ax = usa_without_d['comment_count'].plot(kind='hist', figsize=(14,8), lw=1, ec='lightgray',
                               bins=np.arange(0, 2.6e6, 5e4)-0.5, 
                               logy=True)

plot_configurations(ax, xlbl='Number of comments', ylbl='Number of videos', ticklbl_size=11, lbl_size=12)
formatter = ticker.FuncFormatter(func=lambda x,y: '{:.0f}K'.format(x/1e3))
ax.xaxis.set_major_locator(ticker.MultipleLocator(200000))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatter));
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter(fmt='{x:,.0f}'))
plt.tight_layout()

# %% [markdown]
# *We can conclude that only a small fraction of videos has a lot of comments. By far most videos has no more than 200 000 comments combained. We can continue this topic a bit and look how values in 'comment_count' are arranged*

# %%
usa_without_d['comment_count'].describe().apply(lambda x: format(x, 'f'))
# Out:
# count      6344.000000
# mean       4492.654634
# std       21452.302463
# min           0.000000
# 25%         261.000000
# 50%         920.000000
# 75%        2845.000000
# max      733373.000000
# Name: comment_count, dtype: object

# %%
'{:,.0f}'.format(usa_without_d[usa_without_d['comment_count'] != 0]['comment_count'].min())
# Out:
# '1'

# %%
usa_without_d[usa_without_d['comment_count'] == 1]
# Out:
#           video_id trending_date  \
# 182    oB3SAI2oCqk      17.14.11
# 1177   7xhxjcejONk      17.18.11
# 1379   QaASZecxQww      17.19.11
# 1388   g3VgrgV3kFk      17.19.11
# 1403   aHsfKnrNCG4      17.19.11
# 1602   KkhR9z6pAMs      17.20.11
# 1619   WbYqfpnw7sE      17.20.11
# 2431   qvLyNeMGdR4      17.23.11
# 2646   aXLS_WDIugk      17.24.11
# 5813   kqWQFnH6h-E      17.08.12
# 6704   9U2kr_QfhoQ      17.12.12
# 7545   sVfTvLm-7Ac      17.16.12
# 8389   fmiZUgA-2W4      17.20.12
# 9265   yirvgC-kMq0      17.24.12
# 11641  hFEBexihBGk      18.04.01
# 12111  Xqy62kBAiLk      18.06.01
# 13133  AULfqQCVmWY      18.12.01
# 13316  7sEKooUZi7I      18.13.01
# 13513  62GUa_XUosE      18.14.01
# 13771  yUMalTN2OvM      18.15.01
# 13857  A_yJqOZcIQ0      18.15.01
# 14250  VoUEz9yQJ8w      18.17.01
# 14440  Eafi9hqm3OY      18.18.01
# 14532  9aC3UOu5dR0      18.18.01
# 16281  qDI8LnPq3VY      18.26.01
# 16780  AmZJwThOfzE      18.28.01
# 18297  JGEsZBPkjNY      18.04.02
#
#                                                    title  \
# 182         Caterham Chris Hoy 60 Second Donut Challenge
# 1177   Star Wars & littleBits Droid Inventor Kit: Mov...
# 1379   [HD] Julia Roberts Interview On Today Show 11/...
# 1388                 John Thrasher: Jimbo's here forever
# 1403                 mad eye moody - moving eyeball prop
# 1602   Mali Music and Jennifer Hudson are recording a...
# 1619   The greatest best man speech from 10 year old ...
# 2431               Ford Thunderbird SC commercial (1989)
# 2646                       Jackson Pollock in 60 seconds
# 5813          The Real Reason Tyrese Married His Ex Wife
# 6704   Second-hand cars - transforming old Ford Musta...
# 7545      HIGHLIGHTS: MK Dons U18s 1-0 Cardiff City U18s
# 8389   7 Amazing DIY Christmas Decorations Made From ...
# 9265   Hugh Jackman On Keeping His 21-Year Marriage S...
# 11641        The President's Mystery (1936) - Full Movie
# 12111                    Dazed & Confused - LIVIN Speech
# 13133   Martial Art Grandmaster Does Push ups Hands Free
# 13316                        Laurie Santos: Monkeynomics
# 13513                                   Ressence Youtube
# 13771                                   IoT kit robot #3
# 13857  Build A Self Opening Door Under 20$ With Ardui...
# 14250                  RAPID EYE MOVEMENT⎪Teaser Trailer
# 14440                 Dogs First Snow! Cute Compilation!
# 14532   I Am MLK Jr. Official Teaser | Paramount Network
# 16281                       MTB Skills - Technical Climb
# 16780                           This fox being a derp...
# 18297                            JavaScript Oscilloscope
#
#                                         channel_title  \
# 182                                     Caterham Cars
# 1177                           littleBits Electronics
# 1379                                           NARLtv
# 1388                                      Single Shot
# 1403                                         daronjay
# 1602                                      Tamika Hall
# 1619                                    Kevin Rabatin
# 2431                                     John Sellars
# 2646                            Royal Academy of Arts
# 5813                                       HOTSPOTATL
# 6704                                      Ford Europe
# 7545                                          MK Dons
# 8389                                     Crafty Panda
# 9265                                         PeopleTV
# 11641                                         Freemeo
# 12111                           Navenanthen Gepardieu
# 13133                                    Total Combat
# 13316  NOVA's Secret Life of Scientists and Engineers
# 13513                                RESSENCE WATCHES
# 13771                                         eba era
# 13857                                 Sieuwe Elferink
# 14250                              Tentmaker Pictures
# 14440                                       Slednecks
# 14532                               Paramount Network
# 16281                                 Geoff Mallinson
# 16780                                   Dean Anderson
# 18297                                     Neil Fraser
#
#                    publish_time    views  likes  dislikes  comment_count  \
# 182    2017-11-09T09:59:31.000Z   4850.0   22.0       1.0            1.0
# 1177   2017-11-15T16:18:17.000Z   1387.0   15.0       1.0            1.0
# 1379   2017-11-16T14:11:06.000Z   3545.0   18.0       3.0            1.0
# 1388   2017-11-16T22:50:00.000Z    920.0    3.0       1.0            1.0
# 1403   2017-11-14T13:25:56.000Z   3390.0    9.0       0.0            1.0
# 1602   2013-03-22T22:46:47.000Z   4970.0   13.0       1.0            1.0
# 1619   2017-11-15T03:34:28.000Z   1820.0    2.0       0.0            1.0
# 2431   2016-12-28T05:34:48.000Z   1480.0    5.0       0.0            1.0
# 2646   2016-11-10T19:37:00.000Z  17164.0   47.0       1.0            1.0
# 5813   2017-12-04T19:06:26.000Z   2929.0   13.0       4.0            1.0
# 6704   2017-12-08T10:36:15.000Z  10020.0   70.0       7.0            1.0
# 7545   2017-12-13T16:33:57.000Z  17987.0   26.0       0.0            1.0
# 8389   2017-12-15T15:15:33.000Z   7638.0   18.0       1.0            1.0
# 9265   2017-12-21T14:41:56.000Z   1611.0   24.0       0.0            1.0
# 11641  2013-07-07T21:38:01.000Z  10559.0   39.0       4.0            1.0
# 12111  2013-10-28T11:39:41.000Z  21063.0   72.0       2.0            1.0
# 13133  2017-05-07T12:17:56.000Z   1722.0   17.0       3.0            1.0
# 13316  2013-11-15T15:36:28.000Z   2992.0   28.0       0.0            1.0
# 13513  2017-12-21T15:00:56.000Z  10731.0   29.0       2.0            1.0
# 13771  2014-03-07T22:39:36.000Z   2910.0    1.0       3.0            1.0
# 13857  2017-12-27T21:54:45.000Z   4168.0    8.0       1.0            1.0
# 14250  2018-01-16T14:12:35.000Z   2068.0    0.0       0.0            1.0
# 14440  2016-12-29T10:24:26.000Z   4442.0   14.0       0.0            1.0
# 14532  2018-01-15T13:00:01.000Z   4167.0   76.0      18.0            1.0
# 16281  2015-04-02T12:41:47.000Z   4681.0    2.0       3.0            1.0
# 16780  2017-12-09T19:47:45.000Z   7325.0    6.0       6.0            1.0
# 18297  2018-01-25T06:47:24.000Z   1866.0    8.0       0.0            1.0
#
#                                        thumbnail_link comments_disabled  \
# 182    https://i.ytimg.com/vi/oB3SAI2oCqk/default.jpg             False
# 1177   https://i.ytimg.com/vi/7xhxjcejONk/default.jpg             False
# 1379   https://i.ytimg.com/vi/QaASZecxQww/default.jpg             False
# 1388   https://i.ytimg.com/vi/g3VgrgV3kFk/default.jpg             False
# 1403   https://i.ytimg.com/vi/aHsfKnrNCG4/default.jpg             False
# 1602   https://i.ytimg.com/vi/KkhR9z6pAMs/default.jpg             False
# 1619   https://i.ytimg.com/vi/WbYqfpnw7sE/default.jpg             False
# 2431   https://i.ytimg.com/vi/qvLyNeMGdR4/default.jpg             False
# 2646   https://i.ytimg.com/vi/aXLS_WDIugk/default.jpg             False
# 5813   https://i.ytimg.com/vi/kqWQFnH6h-E/default.jpg             False
# 6704   https://i.ytimg.com/vi/9U2kr_QfhoQ/default.jpg             False
# 7545   https://i.ytimg.com/vi/sVfTvLm-7Ac/default.jpg             False
# 8389   https://i.ytimg.com/vi/fmiZUgA-2W4/default.jpg             False
# 9265   https://i.ytimg.com/vi/yirvgC-kMq0/default.jpg             False
# 11641  https://i.ytimg.com/vi/hFEBexihBGk/default.jpg             False
# 12111  https://i.ytimg.com/vi/Xqy62kBAiLk/default.jpg             False
# 13133  https://i.ytimg.com/vi/AULfqQCVmWY/default.jpg             False
# 13316  https://i.ytimg.com/vi/7sEKooUZi7I/default.jpg             False
# 13513  https://i.ytimg.com/vi/62GUa_XUosE/default.jpg             False
# 13771  https://i.ytimg.com/vi/yUMalTN2OvM/default.jpg             False
# 13857  https://i.ytimg.com/vi/A_yJqOZcIQ0/default.jpg             False
# 14250  https://i.ytimg.com/vi/VoUEz9yQJ8w/default.jpg             False
# 14440  https://i.ytimg.com/vi/Eafi9hqm3OY/default.jpg             False
# 14532  https://i.ytimg.com/vi/9aC3UOu5dR0/default.jpg             False
# 16281  https://i.ytimg.com/vi/qDI8LnPq3VY/default.jpg             False
# 16780  https://i.ytimg.com/vi/AmZJwThOfzE/default.jpg             False
# 18297  https://i.ytimg.com/vi/JGEsZBPkjNY/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 182              False                  False
# 1177             False                  False
# 1379             False                  False
# 1388             False                  False
# 1403             False                  False
# 1602             False                  False
# 1619             False                  False
# 2431             False                  False
# 2646             False                  False
# 5813             False                  False
# 6704             False                  False
# 7545             False                  False
# 8389             False                  False
# 9265             False                  False
# 11641            False                  False
# 12111            False                  False
# 13133            False                  False
# 13316            False                  False
# 13513            False                  False
# 13771            False                  False
# 13857            False                  False
# 14250             True                  False
# 14440            False                  False
# 14532            False                  False
# 16281            False                  False
# 16780            False                  False
# 18297            False                  False
#
#                                              description country  \
# 182    Olympic legend Sir Chris Hoy is no stranger wh...      US
# 1177   A kid inventor movement is afoot, with the Dro...      US
# 1379    Julia Roberts interview on Today Show 11/16/2017      US
# 1388   In an interview with Tia Mitchell of the Flori...      US
# 1403                                                 NaN      US
# 1602   It has been confirmed...Mali Music and Jennife...      US
# 1619   To use this video in a commercial player or in...      US
# 2431   This commercial aired on January 7, 1989 on Am...      US
# 2646   Our Artistic Director Tim Marlow gives a quick...      US
# 5813   Tyrese stopped by the RSMS to clear the air ab...      US
# 6704   REC Watches take Ford Mustangs that are beyond...      US
# 7545   Check out Tommy Hope's stunning winner in the ...      US
# 8389   In this DIY tutorial, we will show you how to ...      US
# 9265   Hugh Jackman talks about the crazy ups and cra...      US
# 11641  A millionaire with a crumbling personal life c...      US
# 12111  Matthew McConaughey in the modern classic, Daz...      US
# 13133  Watch how the experts do push ups. Two hands O...      US
# 13316  Laurie Santos gives some monkeys money and lea...      US
# 13513  “What if” by #Ressence. \n\nMake sure to turn ...      US
# 13771                                                NaN      US
# 13857  https://www.instructables.com/id/Make-a-Automa...      US
# 14250  From Director Peter Bishai (Colors of Heaven),...      US
# 14440  When dogs go out for the first snow, these cut...      US
# 14532  I Am MLK Jr. looks at Dr. King, his experience...      US
# 16281  Riding some of the single track at Ourimbah ba...      US
# 16780  I'm not really sure what he was trying to acco...      US
# 18297  Generate images on an oscilloscope (vectorscop...      US
#
#                                                     tags  category_id
# 182    ,'caterham','chris hoy','caterham seven','avon...        801.0
# 1177   ,'littlebits','starwars','inventorswanted','dr...        301.0
# 1379   ,'julia roberts','interview','today','show','2...        806.0
# 1388   ,'fsu','florida state','seminoles','seminole',...        802.0
# 1403                                           ,'[none]'        600.0
# 1602   ,'mali music and jennifer hudson','jennifer hu...        806.0
# 1619                                           ,'[none]'        804.0
# 2431   ,'1989','80s commercial','kamr','amarillo','te...        806.0
# 2646   ,'royal academy of arts','art','visual arts','...        806.0
# 5813           ,'whta','tyrese','hot 107.9','hotspotatl'        806.0
# 6704                          ,'yt:cc=on','ford mustang'        801.0
# 7545              ,'tommy hope','mk dons','cardiff city'        802.0
# 8389   ,'diy','christmas tree','christmas decorations...        804.0
# 9265   ,'hughjackman','hugh jackman','celebrities','l...        806.0
# 11641  ,'freemeo','films','film','public domain','mov...        201.0
# 12111  ,'speech (activity)','dazed & confused (magazi...        806.0
# 13133  ,'martial art','push ups','grandmaster','hands...        802.0
# 13316                                          ,'[none]'        301.0
# 13513                                          ,'[none]'        201.0
# 13771                       ,'aruduino','robot','sensor'        600.0
# 13857                                          ,'[none]'        804.0
# 14250  ,'francois arnaud','peter bishai','sleep depri...        201.0
# 14440                           ,'dogs','animals','cute'        700.0
# 14532  ,'paramount network','mlk','mlk jr','freedom r...        806.0
# 16281                                          ,'[none]'        806.0
# 16780  ,'animal','animals','cute','derp','animals bei...        700.0
# 18297  ,'javascript','oscilloscope','vectorscope','au...        301.0

# %% [markdown]
# *These are the videos (27 in total) in US trending list that have the lowesst number of comments (1) when they first appeared on trending list*

# %%
ax = usa['views'].plot(kind='hist', bins=np.arange(0, 8.5e6, 2.5e5)-0.5, figsize=(16,8), 
                           logy=True, lw=1, ec='lightgray');
plot_configurations(ax, xlbl='Number of views', ylbl='Number of videos', ticklbl_size=11, lbl_size=12)
formatter = ticker.FuncFormatter(func=lambda x,y: '{:.1f}M'.format(x/1e6))
ax.xaxis.set_major_locator(ticker.MultipleLocator(500000))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatter));
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter(fmt='{x:,.0f}'))
plt.tight_layout()

# %% [markdown]
# ## 5th: What are the relationship between the number of tags and the number of views? Does this relationship appears in all countries?

# %%
usa['num_tags'] = usa['tags'].astype(str).apply(lambda x: len(x.split(',')) if x != '[none]' else 0)

# %%
ax = usa.plot(kind='scatter', x='num_tags', y='views', figsize=(14,8))
plot_configurations(ax, xlbl='Number of tags', ylbl='Number of views')

# %% [markdown]
# *We can see that in US biggest part of videos has no more than **30** tags.*

# %% [markdown]
# *I think it would also be cool to take a look what relationship we can spot between description lenght and number of views.*

# %% [markdown]
# ## Relationship between description length and number of views

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.scatterplot(x=usa['description'].str.len(), y=usa['views'])
plot_configurations(ax, xlbl='Description length', ylbl='Number of views')

# %% [markdown]
# *Looks like Scatter Plot above displays legit relationship between number of views and lenght of description - **the longer the video description, the lower the number of views**. I will try to edit column **'num_tags'** so I can visualize relationship between the number of tags and the number of views. If I havent made changes that I did not managed to figure out that issue.*

# %% [markdown]
# # Text Classification

# %% [markdown]
# #### Cleaning the text

# %%
! pip install nltk
! pip install textblob
# Out:
# Requirement already satisfied: nltk in c:\users\username\downloads\programs\anaconda\lib\site-packages (3.5)
# Requirement already satisfied: regex in c:\users\username\downloads\programs\anaconda\lib\site-packages (from nltk) (2020.10.15)
# Requirement already satisfied: tqdm in c:\users\username\downloads\programs\anaconda\lib\site-packages (from nltk) (4.50.2)
# Requirement already satisfied: click in c:\users\username\downloads\programs\anaconda\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\users\username\downloads\programs\anaconda\lib\site-packages (from nltk) (0.17.0)
# Collecting textblob
#   Downloading textblob-0.15.3-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\username\downloads\programs\anaconda\lib\site-packages (from textblob) (3.5)
# Requirement already satisfied: joblib in c:\users\username\downloads\programs\anaconda\lib\site-packages (from nltk>=3.1->textblob) (0.17.0)
# Requirement already satisfied: tqdm in c:\users\username\downloads\programs\anaconda\lib\site-packages (from nltk>=3.1->textblob) (4.50.2)
# Requirement already satisfied: regex in c:\users\username\downloads\programs\anaconda\lib\site-packages (from nltk>=3.1->textblob) (2020.10.15)
# Requirement already satisfied: click in c:\users\username\downloads\programs\anaconda\lib\site-packages (from nltk>=3.1->textblob) (7.1.2)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3

# %%
import re
import string
from textblob import TextBlob
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
stop_words = stopwords.words("english")

# %%
def text_preproc(x):
  x = x.lower()
  # x = ' '.join(wordnet.lemmatize(word, 'v') for word in x.split())
  x = ' '.join([word for word in x.split(' ') if word not in stop_words])
  x = x.encode('ascii', 'ignore').decode()
  x = re.sub(r'https*\S+', ' ', x)
  x = re.sub(r'@\S+', ' ', x)
  x = re.sub(r'#\S+', ' ', x)
  x = re.sub(r'\'\w+', '', x)
  x = re.sub('[%s]' % re.escape(string.punctuation), ' ', x)
  x = re.sub(r'\w*\d+\w*', '', x)
  x = re.sub(r'\s{2,}', ' ', x)
  return x
usa['clean_text'] = usa.text.apply(text_preproc)

# %% [markdown]
# ## Repeat all previous steps with Canada dataset

# %%
can = pd.read_csv('CAvideos.csv', sep=';')
can.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#                publish_time       views      likes  dislikes  comment_count  \
# 0  2017-11-10T17:00:03.000Z  17158579.0   787425.0   43420.0       125882.0
# 1  2017-11-13T17:00:00.000Z   1014651.0   127794.0    1688.0        13030.0
# 2  2017-11-12T19:05:24.000Z   3191434.0   146035.0    5339.0         8181.0
# 3  2017-11-12T18:01:41.000Z   2095828.0   132239.0    1989.0        17518.0
# 4  2017-11-09T11:04:14.000Z  33523622.0  1634130.0   21082.0        85067.0
#
#                                    thumbnail_link comments_disabled  \
# 0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg             False
# 1  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg             False
# 2  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg             False
# 3  https://i.ytimg.com/vi/d380meD0W0M/default.jpg             False
# 4  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg             False
#
#   ratings_disabled video_error_or_removed  \
# 0            False                  False
# 1            False                  False
# 2            False                  False
# 3            False                  False
# 4            False                  False
#
#                                          description country  \
# 0  Eminem's new track Walk on Water ft. Beyoncé i...      CA
# 1  STill got a lot of packages. Probably will las...      CA
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...      CA
# 3  I know it's been a while since we did this sho...      CA
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...      CA
#
#                                                 tags  category_id
# 0  ,'eminem','walk','on','water','aftermath/shady...        600.0
# 1  ,'plush','bad unboxing','unboxing','fan mail',...        805.0
# 2  ,'racist superman','rudy','mancuso','king','ba...        805.0
# 3  ,'ryan','higa','higatv','nigahiga','i dare you...        806.0
# 4  ,'edsheeran','ed sheeran','acoustic','live','c...        600.0

# %%
can.head(1).transpose()
# Out:
#                                                                         0
# video_id                                                      n1WpP7iowLc
# trending_date                                                    17.14.11
# title                          Eminem - Walk On Water (Audio) ft. Beyoncé
# channel_title                                                  EminemVEVO
# publish_time                                     2017-11-10T17:00:03.000Z
# views                                                         1.71586e+07
# likes                                                              787425
# dislikes                                                            43420
# comment_count                                                      125882
# thumbnail_link             https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             Eminem's new track Walk on Water ft. Beyoncé i...
# country                                                                CA
# tags                    ,'eminem','walk','on','water','aftermath/shady...
# category_id                                                           600

# %%
can.shape
# Out:
# (42019, 17)

# %% [markdown]
# *Dataset consist of 42 019 rows and 17 columns.*

# %%
can.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'publish_time',
#        'views', 'likes', 'dislikes', 'comment_count', 'thumbnail_link',
#        'comments_disabled', 'ratings_disabled', 'video_error_or_removed',
#        'description', 'country', 'tags', 'category_id'],
#       dtype='object')

# %% [markdown]
# *Unique videos in a dataset (Canada)*

# %%
count_of_unique_videos_can = can['video_id'].unique().shape[0]
count_of_unique_videos_can
# Out:
# 23861

# %% [markdown]
# *Canada dateset contains 23 861 unique videos*

# %% [markdown]
# ## Column Data types (CANADA)

# %%
can.dtypes
# Out:
# video_id                   object
# trending_date              object
# title                      object
# channel_title              object
# publish_time               object
# views                     float64
# likes                     float64
# dislikes                  float64
# comment_count             float64
# thumbnail_link             object
# comments_disabled          object
# ratings_disabled           object
# video_error_or_removed     object
# description                object
# country                    object
# tags                       object
# category_id               float64
# dtype: object

# %% [markdown]
# *Repeat same process that we did with previous dataset.*

# %%
column_datatypes_to_change2 = ['views', 'likes', 'dislikes', 'comment_count']
for column in column_datatypes_to_change2:
    usa[column] = usa[column].astype(int)

# %%
can['trending_date'] = pd.to_datetime(can['trending_date'],errors='coerce', format='%y.%d.%m')
can['publish_time'] = pd.to_datetime(can['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# %%
can.dtypes
# Out:
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# publish_time              datetime64[ns]
# views                            float64
# likes                            float64
# dislikes                         float64
# comment_count                    float64
# thumbnail_link                    object
# comments_disabled                 object
# ratings_disabled                  object
# video_error_or_removed            object
# description                       object
# country                           object
# tags                              object
# category_id                      float64
# dtype: object

# %% [markdown]
# ## Missing data (CANADA)

# %%
for i in can.columns:
    null_rate = can[i].isna().sum()/len(can)*100
    if null_rate >= 0:
        print("Column '{}' null rate: {}%".format(i,round(null_rate,2)))
# Out:
# Column 'video_id' null rate: 0.0%
# Column 'trending_date' null rate: 5.68%
# Column 'title' null rate: 4.7%
# Column 'channel_title' null rate: 4.85%
# Column 'publish_time' null rate: 5.68%
# Column 'views' null rate: 5.68%
# Column 'likes' null rate: 5.68%
# Column 'dislikes' null rate: 5.68%
# Column 'comment_count' null rate: 5.68%
# Column 'thumbnail_link' null rate: 5.68%
# Column 'comments_disabled' null rate: 5.68%
# Column 'ratings_disabled' null rate: 5.68%
# Column 'video_error_or_removed' null rate: 5.68%
# Column 'description' null rate: 8.32%
# Column 'country' null rate: 6.66%
# Column 'tags' null rate: 6.66%
# Column 'category_id' null rate: 8.84%

# %% [markdown]
# *Column 'category_id' has the most missing values - almost 9% is missing.*

# %%
can.isnull().sum()
# Out:
# video_id                     0
# trending_date             2387
# title                     1976
# channel_title             2037
# publish_time              2387
# views                     2387
# likes                     2387
# dislikes                  2387
# comment_count             2387
# thumbnail_link            2387
# comments_disabled         2387
# ratings_disabled          2387
# video_error_or_removed    2387
# description               3494
# country                   2798
# tags                      2798
# category_id               3715
# dtype: int64

# %% [markdown]
# *We can see that all columns (except 'video_id') contains couple thousands of NULL values. There are no 1 right way to deal with them.*

# %% [markdown]
# *Since I want to do analysis on columns **Views**, **Likes,** **Dislikes** and **Comment_count**, we have to get rid of missing values in these columns. We could replace missing values with average values in each column, but this time I think we can replace NaN values with 0 as well.*

# %%
can['views'] = can['views'].fillna(0)
can['likes'] = can['likes'].fillna(0)
can['dislikes'] = can['dislikes'].fillna(0)
can['comment_count'] = can['comment_count'].fillna(0)

# %%
can.isnull().sum()
# Out:
# video_id                     0
# trending_date             2387
# title                     1976
# channel_title             2037
# publish_time              2387
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link            2387
# comments_disabled         2387
# ratings_disabled          2387
# video_error_or_removed    2387
# description               3494
# country                   2798
# tags                      2798
# category_id               3715
# dtype: int64

# %% [markdown]
# ## Disabled Comments, Ratings & Errors (Canada)

# %%
can["video_error_or_removed"].value_counts()
# Out:
# False    39605
# True        27
# Name: video_error_or_removed, dtype: int64

# %% [markdown]
# *Out of videos that appeared on trending list (40 879) only **23** videos had errors or they were removed.*

# %% [markdown]
# can["comments_disabled"].value_counts()

# %% [markdown]
# *Only **569** videos had their comments disabled (as seen in code below).*

# %% [markdown]
# *We can see similar situation with videos that had their ratings disabled*

# %%
can["ratings_disabled"].value_counts()
# Out:
# False    39408
# True       224
# Name: ratings_disabled, dtype: int64

# %% [markdown]
# *Again, only a small portion (234) of all videos had their ratings disabled.*

# %% [markdown]
# #### Videos that remained the most on trending video list (CANADA)

# %%
can['title'].value_counts().head(20)
# Out:
# Most Popular Violin Covers of Popular Songs 2018 || Best Instrumental Violin Covers 2018             15
# Drake - God's Plan (Official Audio)                                                                  15
# Bruno Mars,Charlie Puth,Ed Sheeran Best Christmas Songs,Greatest Hits Pop Playlist Christmas 2018    13
# Deleted video                                                                                        11
# Merry Christmas 2018 - Top Christmas Songs Playlist 2018 - Best Christmas Songs Ever                 10
# Mission: Impossible - Fallout (2018) - Official Trailer - Paramount Pictures                          9
# Maroon 5 - Wait                                                                                       9
# Nicki Minaj - Chun-Li                                                                                 9
# G-Eazy - No Limit REMIX ft. A$AP Rocky, Cardi B, French Montana, Juicy J, Belly                       8
# Eminem - River ft. Ed Sheeran                                                                         8
# Marvel Studios' Avengers: Infinity War Official Trailer                                               8
# Post Malone - rockstar ft. 21 Savage                                                                  8
# Childish Gambino - This Is America (Official Video)                                                   8
# Michigan Meteor Jan 16 2018                                                                           7
# lofi hip hop radio - beats to relax/study to                                                          7
# Post Malone Feat. Ty Dolla $ign - Psycho (Official Audio)                                             7
# Top 10 Best Super Bowl 52 Commercials (2018 Funniest Ads Superbowl LII)                               7
# Do you hear Yanny or Laurel?                                                                          7
# Lucas the Spider - Playtime                                                                           7
# Alexa randomly laughing compilation                                                                   7
# Name: title, dtype: int64

# %% [markdown]
# *Table above shows that in the CANADA's dataset the 1st place for the video that remained the most on trending video list occupies 2 songs - called **"Drake - God's Plan (Official Audio)",** and **"Most Popular Violin Covers of Popular Songs 2018 || Best Instrumental Violin Covers 2018"**, each of them appeared on the list 15 times.*

# %% [markdown]
# ## Top Categories (CANADA)

# %%
can['category_id'].value_counts().head(120)
# Out:
# 806.0    12909
# 804.0     3832
# 102.0     3789
# 600.0     3718
# 805.0     3694
#          ...
# 463.0        1
# 424.0        1
# 515.0        1
# 527.0        1
# 433.0        1
# Name: category_id, Length: 98, dtype: int64

# %%
# Based on data that is found in categories.csv we can found out the distribution of videos by Categories

politics = can.loc[(can.category_id >= 100) & (can.category_id <= 102)].count()[0]
cinema = can.loc[(can.category_id >= 200) & (can.category_id <= 204)].count()[0]
education = can.loc[(can.category_id >= 300) & (can.category_id <= 302)].count()[0]
diy_and_beauty = can.loc[(can.category_id >= 400) & (can.category_id <= 497)].count()[0]
travel_and_events = can.loc[(can.category_id >= 500) & (can.category_id <= 551)].count()[0]
music = can.loc[(can.category_id >= 600) & (can.category_id <= 600)].count()[0]
animals = can.loc[(can.category_id >= 700) & (can.category_id <= 700)].count()[0]
entertainment = can.loc[(can.category_id >= 800) & (can.category_id <= 806)].count()[0]

categories = [politics, cinema, education, diy_and_beauty, travel_and_events, music, animals, entertainment]
explode = [0,0,0,0,.5,0,.25,0]
colors = ['magenta', 'cyan', 'pink', 'salmon', 'khaki', 'lightblue', 'lightgreen', 'orange']
labels = ['Politics', 'Cinema', 'Education', 'DIY&Beauty', 'Travel&Events', 'Music', 'Animals', 'Entertainment']

#plt.title('Distribution of videos by Categories!')

plt.pie(categories, labels=labels, radius=3, colors=colors, autopct='%.2f %%', pctdistance=0.8, explode=explode)
plt.show()

# %% [markdown]
# *In the Pie Chart above we see that when looking at CANADIAN dateset Entertainment category contains the largest number of trending videos among other categories **(64,69%),** followed by Politic category **(10,06%),** followed by Music category **(9,71%),** and so on!*

# %% [markdown]
# ## Views of the videos (CANADA)

# %% [markdown]
# #### A trending video with the fewest views (excluding those with 0 views)

# %%
unique_videos_can_least_views = (can[can['views'] > 0].sort_values(by='views', ascending=True)).drop_duplicates(subset=['video_id']).head(1)
unique_videos_can_least_views
# Out:
#           video_id trending_date                                      title  \
# 35699  bz91MAdY6FQ    2018-05-14  ''Gala Artis 2018'' Le numéro d'ouverture
#
#       channel_title        publish_time  views  likes  dislikes  \
# 35699      mart lat 2018-05-14 00:43:35  733.0   10.0       4.0
#
#        comment_count                                  thumbnail_link  \
# 35699            0.0  https://i.ytimg.com/vi/bz91MAdY6FQ/default.jpg
#
#       comments_disabled ratings_disabled video_error_or_removed  \
# 35699             False            False                  False
#
#                                              description country  \
# 35699  Anim.: Maripier Morin et Jean-Philippe Dion. L...      CA
#
#                                                     tags  category_id
# 35699  ,'gala','artis','2018','numéro d'ouverture','y...        806.0

# %% [markdown]
# *Video with the LEAST views is called **"Gala Artis 2018 Le numéro d'ouverture"** from channel "mart lat" which had accumulated 733 views.*

# %% [markdown]
# #### TOP 5 trending videos with the LEAST Views - excluding those with 0 views

# %%
unique_videos_can_least_views = (can[can['views'] > 0].sort_values(by='views', ascending=True)).drop_duplicates(subset=['video_id']).head(5)
unique_videos_can_least_views
# Out:
#           video_id trending_date  \
# 35699  bz91MAdY6FQ    2018-05-14
# 18577  _QPStIydtgg    2018-02-14
# 18607  CGv_PLrWArs    2018-02-14
# 21040  MTtFpn9C7Q4    2018-02-26
# 581    0ayARJdf7I4    2017-11-16
#
#                                                    title    channel_title  \
# 35699          ''Gala Artis 2018'' Le numéro d'ouverture         mart lat
# 18577  Canadian Olympian receives death threats from ...     The National
# 18607  Raptors Post-Game: DeMar DeRozan - February 13...  Toronto Raptors
# 21040  Simon Olivier Fecteau créateur des derniers By...         mart lat
# 581                        018 Algebra Lineal 18-10-2011        udearroba
#
#              publish_time   views  likes  dislikes  comment_count  \
# 35699 2018-05-14 00:43:35   733.0   10.0       4.0            0.0
# 18577 2018-02-14 03:45:33  1000.0   46.0      19.0            0.0
# 18607 2018-02-14 03:32:57  1023.0   65.0       5.0           23.0
# 21040 2018-02-26 03:18:13  1107.0   14.0       1.0            3.0
# 581   2017-11-15 18:20:06  1141.0    0.0       0.0            0.0
#
#                                        thumbnail_link comments_disabled  \
# 35699  https://i.ytimg.com/vi/bz91MAdY6FQ/default.jpg             False
# 18577  https://i.ytimg.com/vi/_QPStIydtgg/default.jpg              True
# 18607  https://i.ytimg.com/vi/CGv_PLrWArs/default.jpg             False
# 21040  https://i.ytimg.com/vi/MTtFpn9C7Q4/default.jpg             False
# 581    https://i.ytimg.com/vi/0ayARJdf7I4/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 35699            False                  False
# 18577            False                  False
# 18607            False                  False
# 21040            False                  False
# 581              False                  False
#
#                                              description country  \
# 35699  Anim.: Maripier Morin et Jean-Philippe Dion. L...      CA
# 18577  Canadian Olympian Kim Boutin received threats ...      CA
# 18607  DeMar DeRozan addresses the media following To...      CA
# 21040  Simon Olivier Fecteau renoue avec son ingrat p...      CA
# 581                                       Base ortogonal      CA
#
#                                                     tags  category_id
# 35699  ,'gala','artis','2018','numéro d'ouverture','y...        806.0
# 18577  ,'kim boutin','canadian olympian','bronze meda...        102.0
# 18607  ,'nba','toronto','toronto raptors','raptors','...        802.0
# 21040  ,'simon olivier fecteau','bye bye','en auditio...        806.0
# 581                                            ,'[none]'        302.0

# %% [markdown]
# ### Video with the maximum number of views (CANADA)

# %%
can[can['views'] == can['views'].max()].transpose()
# Out:
#                                                                      6102
# video_id                                                      FlsCjmMhFmw
# trending_date                                         2017-12-13 00:00:00
# title                   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# channel_title                                           YouTube Spotlight
# publish_time                                          2017-12-06 17:58:51
# views                                                         1.37843e+08
# likes                                                         3.01448e+06
# dislikes                                                      1.60238e+06
# comment_count                                                      817582
# thumbnail_link             https://i.ytimg.com/vi/FlsCjmMhFmw/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             YouTube Rewind 2017. Celebrating the videos, p...
# country                                                                CA
# tags                    ,'rewind','rewind 2017','youtube rewind 2017',...
# category_id                                                           806

# %%
can['views'].max()
# Out:
# 137843120.0

# %% [markdown]
# *Video with the **MOST** views is called **"YouTube Rewind: The Shape of 2017 | #YouTubeRe..."** from channel "YouTube Spotlight" which had accumulated more than 137 million views.*

# %% [markdown]
# #### TOP 5 videos with the MOST Views

# %%
unique_videos_can_most_views = can.sort_values(by='views', ascending=False).drop_duplicates(subset=['video_id'])
unique_videos_can_most_views[['title', 'views']].head(5)
# Out:
#                                                    title        views
# 6102   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  137843120.0
# 35441  Childish Gambino - This Is America (Official V...   98938809.0
# 4905   Marvel Studios' Avengers: Infinity War Officia...   89930713.0
# 37577                BTS (방탄소년단) 'FAKE LOVE' Official MV   80738011.0
# 22635  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...   61163906.0

# %%
without_dublicates_can = can.drop_duplicates(subset=['video_id'])

# %% [markdown]
# ## The most Likes, Comments, Dislikes and Views (CANADA)

# %%
def visualize_most(can, column, num=10):
    sorted_df_can = can.sort_values(column, ascending=False).iloc[:num]
    
    ax = sorted_df_can[column].plot.bar(color=lightgreen)
    
    # customizes the video titles, for asthetic purposes for the bar chart
    labels = []
    for item in sorted_df_can['title']:
        labels.append(item[:12] + '...')
    ax.set_xticklabels(labels, rotation=45, fontsize=10)
    
    plt.show()

# %%
visualize_most(unique_videos_can_most_views, 'views')

# %%
visualize_most(can, 'views', num=15)

# %%
visualize_most(can, 'comment_count')

# %%
visualize_most(can, 'likes', num=15)

# %%
visualize_most(can, 'dislikes', num=15)

# %%
visualize_most(unique_videos_can_most_dislikes, 'dislikes')

# %%
unique_videos_can_most_dislikes = can.sort_values(by='dislikes', ascending=False).drop_duplicates(subset=['video_id'])
unique_videos_can_most_dislikes[['title', 'dislikes']].head(5)
# Out:
#                                                    title   dislikes
# 6102   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  1602383.0
# 3079   Jake Paul - It's Everyday Bro (Remix) [feat. G...   504340.0
# 15278                         Suicide: Be Here Tomorrow.   461660.0
# 299    Jake Paul - Saturday Night (Song) feat. Nick C...   200391.0
# 6903               PSA from Chairman of the FCC Ajit Pai   190227.0

# %% [markdown]
# ## Most Popular Trending Channels (CANADA)

# %%
can.groupby(['channel_title']).size().sort_values(ascending=False).head(10)
# Out:
# channel_title
# SET India                             192
# MSNBC                                 189
# FBE                                   188
# The Young Turks                       186
# REACT                                 183
# VikatanTV                             182
# CNN                                   182
# The Late Show with Stephen Colbert    172
# RadaanMedia                           168
# ARY Digital                           168
# dtype: int64

# %%
trending_channels_can = can.groupby(['channel_title']).size().sort_values(ascending=False).head(10)
sns.barplot(trending_channels_can.values, trending_channels_can.index.values, palette = 'viridis')
plt.title('Top 10 Most Popular Trending Channels')
plt.xlabel('Video Count')
plt.show()
# Out:
# C:\Users\username\Downloads\Programs\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# *We can conclude that in Canada the most popular channels are news-based, like **SET India** that is entertainment pay television channel, followed by **MSNBC** (news-based TV channel) and so on. The only talk-show-based channel in TOP 10 list is **The Late Show with Stephen Colbert**.*

# %% [markdown]
# ## Most Popular Publishing Day & Time (CANADA)

# %%
can['day_published'] = can['publish_time'].dt.day_name()
can['hour_published'] = can['publish_time'].dt.hour

# %%
ax = can['day_published'].value_counts().plot(
    kind='bar', figsize=(10,6), rot=0)

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.tight_layout()

# %% [markdown]
# *As seen in table above, the most trending videos in Canada was published in working days - **Monday, Thursday, Tuesday, Wednesday and Friday**, the last one (Friday) had significant more trending videos than the rest of working days. But on holidays there were slighly less trending videos.*

# %% [markdown]
# ### Most Popular Publishing Hour

# %%
ax_can = can['hour_published'].value_counts().sort_index().plot(
    kind='bar', figsize=(14,8), rot=0)

ax_can.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.tight_layout()

# %% [markdown]
# *We can see that the most trending videos in Canada was published in the afternoon, gaining rapid increase at **1:00 p.m** and reaching the maximum at **4 p.m.,** while early morning hours (6:00 a.m. - 10.00 a.m) is the time when you dont want to publish a video if you want it to go viral.*

# %% [markdown]
# ### Correlations (CANADA)

# %%
columns_needed_can = ['views', 'likes', 'dislikes', 'comment_count'] # only these columns needed this time
corr_matrix_can = can[columns_needed_can].corr()
corr_matrix_can
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.829952  0.558564       0.694395
# likes          0.829952  1.000000  0.460500       0.837043
# dislikes       0.558564  0.460500  1.000000       0.643210
# comment_count  0.694395  0.837043  0.643210       1.000000

# %% [markdown]
# ## The table above shows that there are correlation between ...

# %%
can['like_dislike_ratio'] = can['likes'] / can['dislikes']
can['comments_percentage'] = can['comment_count'] / can['views']
can['reaction_percentage'] = (can['likes'] + can['dislikes']) / can['views']

# %%
correlation_can = can[['views', 'likes', 'dislikes', 'comment_count', 'like_dislike_ratio', 'comments_percentage', 'reaction_percentage']]
corr_can = correlation.corr()

mask_can = np.zeros_like(corr_can, dtype=np.bool)
mask_can[np.triu_indices_from(mask_can)] = True

cmap_can = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr_can, mask=mask_can, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# *Matrix above shows that there are several moderate correlations. Just like we saw previously in USA dataset, also in this Canada dataset most noticable correlation is comment count is positevely related with views, likes and dislikes. That means that people who react with a like or dislike are also more likely leave a comment after watching the video.*

# %% [markdown]
# # ADDITIONAL TASKS (CAN):

# %% [markdown]
# ## 1st: How many comments a video has when first appearing on the trending list?

# %%
can_without_d = can.drop_duplicates(subset=['video_id'])
ax = can_without_d['comment_count'].plot(kind='hist', figsize=(14,8), lw=1, ec='lightgray',
                               bins=np.arange(0, 2.6e6, 5e4)-0.5, 
                               logy=True)

plot_configurations(ax, xlbl='Number of comments', ylbl='Number of videos', ticklbl_size=11, lbl_size=12)
formatter = ticker.FuncFormatter(func=lambda x,y: '{:.0f}K'.format(x/1e3))
ax.xaxis.set_major_locator(ticker.MultipleLocator(200000))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatter));
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter(fmt='{x:,.0f}'))
plt.tight_layout()

# %% [markdown]
# *Very similar to what can be seen in US dataset.*

# %%
can_without_d['comment_count'].describe().apply(lambda x: format(x, 'f'))
# Out:
# count     23417.000000
# mean       2647.468805
# std       10444.414659
# min           0.000000
# 25%         283.000000
# 50%         873.000000
# 75%        2229.000000
# max      692311.000000
# Name: comment_count, dtype: object

# %%
'{:,.0f}'.format(can_without_d[can_without_d['comment_count'] != 0]['comment_count'].min())
# Out:
# '1'

# %%
can_without_d[can_without_d['comment_count'] == 1].head()
# Out:
#          video_id trending_date  \
# 42    t3FYESkzjUI      17.14.11
# 422   e3cAjHLA-iU      17.16.11
# 1107  oB7ElnIr1AQ      17.19.11
# 1652  X4wQLfMtKGM      17.21.11
# 4546  uwjk8NMU8RU      17.05.12
#
#                                                   title        channel_title  \
# 42                 Emotionally Responsive Digital Human        Soul Machines
# 422   Il fait la statue et échappe à la police penda...        jean registre
# 1107  Maxime Villemaire, Marc-Olivier D'Amour et Fra...        David Lagassé
# 1652  Maple Leafs Pre-Game: Mitch Marner - November ...  Toronto Maple Leafs
# 4546                               En revenant du frigo   La Famille du Lait
#
#                   publish_time   views  likes  dislikes  comment_count  \
# 42    2017-10-31T01:11:48.000Z  3684.0    4.0       5.0            1.0
# 422   2017-11-15T03:09:59.000Z  5386.0    7.0       2.0            1.0
# 1107  2017-11-18T06:58:18.000Z  6587.0    3.0       0.0            1.0
# 1652  2017-11-20T17:33:57.000Z  1730.0   25.0       0.0            1.0
# 4546  2017-12-03T23:43:59.000Z  4401.0    6.0       0.0            1.0
#
#                                       thumbnail_link comments_disabled  \
# 42    https://i.ytimg.com/vi/t3FYESkzjUI/default.jpg             False
# 422   https://i.ytimg.com/vi/e3cAjHLA-iU/default.jpg             False
# 1107  https://i.ytimg.com/vi/oB7ElnIr1AQ/default.jpg             False
# 1652  https://i.ytimg.com/vi/X4wQLfMtKGM/default.jpg             False
# 4546  https://i.ytimg.com/vi/uwjk8NMU8RU/default.jpg             False
#
#      ratings_disabled video_error_or_removed  \
# 42              False                  False
# 422             False                  False
# 1107            False                  False
# 1652            False                  False
# 4546            False                  False
#
#                                             description country  \
# 42          Soul Machines is making machines more human      CA
# 422                                                 NaN      CA
# 1107  Les joueurs des 3L en viennent au coup avec la...      CA
# 1652  Mitch Marner speaks with the media ahead of to...      CA
# 4546  Paroles \n\nC’est ennnnnnnnnnnnnnnnn… Revenant...      CA
#
#                                                    tags  category_id
# 42    ,'artificial intelligence','digital human','vi...        804.0
# 422                                           ,'[none]'        804.0
# 1107  ,'maxime villemaire','marc-olivier d'amour','f...        802.0
# 1652  ,'toronto','toronto maple leafs','leafs','mapl...        802.0
# 4546                                          ,'[none]'        805.0

# %% [markdown]
# *These are the videos **(32 in total)** in Canada's trending list that have the lowesst number of comments (1) when they first appeared on trending list*

# %% [markdown]
# ## 2nd: How many videos in each country that had their Dislikes more than their Likes when first appeared on the trending list (CAN)

# %%
can_without_d = can.drop_duplicates(subset=['video_id'])

# %%
can_without_d['net_dislikes'] = (can_without_d['dislikes'] - can_without_d['likes'])
can_without_d[can_without_d['net_dislikes'] > 0].sort_values(by='net_dislikes', ascending=False)
# Out:
# <ipython-input-16-eca38ebf0964>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   can_without_d['net_dislikes'] = (can_without_d['dislikes'] - can_without_d['likes'])
#           video_id trending_date  \
# 6424   LFhT6H6pRWg      17.15.12
# 6436   8d_202l55LU      17.15.12
# 35825  QW8whgmyTNU      18.15.05
# 6454   8I_NkJ8VTEI      17.15.12
# 40622  GnGPAYvve1A      18.08.06
# ...            ...           ...
# 38006  4Sx-D6aQ630      18.25.05
# 23136  r74rJC_5tYs      18.08.03
# 13780  8SAr4URIafA      18.21.01
# 31675  _hqzg37D_nU      18.24.04
# 42     t3FYESkzjUI      17.14.11
#
#                                                    title  \
# 6424               PSA from Chairman of the FCC Ajit Pai
# 6436            The FCC repeals its net neutrality rules
# 35825                      This Is America: Women's Edit
# 6454                  Judge Roy Moore Campaign Statement
# 40622                         #ProudToCreate: Pride 2018
# ...                                                  ...
# 38006  30 things went wrong from royal wedding //  Pr...
# 23136  Arie Luyendyk Jr. Explains Why He Proposed To ...
# 13780                                        My video c3
# 31675  TORONTO NORTH YORK VAN STRIKE PEDESTRIAN  *STR...
# 42                  Emotionally Responsive Digital Human
#
#               channel_title              publish_time     views    likes  \
# 6424           Daily Caller  2017-12-13T22:52:57.000Z  649781.0   5505.0
# 6436        Washington Post  2017-12-14T18:49:06.000Z  985179.0   4870.0
# 35825         Nicole Arbour  2018-05-12T22:42:24.000Z  868163.0  17644.0
# 6454   Roy Moore for Senate  2017-12-14T03:04:05.000Z  603783.0   3307.0
# 40622     YouTube Spotlight  2018-06-07T19:08:51.000Z  597669.0  29781.0
# ...                     ...                       ...       ...      ...
# 38006            RWANDA5 TV  2018-05-20T04:12:22.000Z  339125.0    487.0
# 23136              PeopleTV  2018-03-08T00:00:00.000Z   13489.0     41.0
# 13780         robert taylor  2018-01-19T12:03:06.000Z  124575.0    165.0
# 31675     Dont Snooz MrNews  2018-04-23T23:29:12.000Z   11862.0      9.0
# 42            Soul Machines  2017-10-31T01:11:48.000Z    3684.0      4.0
#
#        dislikes  comment_count  \
# 6424   140080.0        16730.0
# 6436   110709.0        19843.0
# 35825   75955.0            0.0
# 6454    46779.0            0.0
# 40622   71617.0        55110.0
# ...         ...            ...
# 38006     496.0          133.0
# 23136      50.0           18.0
# 13780     171.0            0.0
# 31675      12.0           14.0
# 42          5.0            1.0
#
#                                           thumbnail_link comments_disabled  \
# 6424      https://i.ytimg.com/vi/LFhT6H6pRWg/default.jpg             False
# 6436      https://i.ytimg.com/vi/8d_202l55LU/default.jpg             False
# 35825     https://i.ytimg.com/vi/QW8whgmyTNU/default.jpg              True
# 6454      https://i.ytimg.com/vi/8I_NkJ8VTEI/default.jpg              True
# 40622     https://i.ytimg.com/vi/GnGPAYvve1A/default.jpg             False
# ...                                                  ...               ...
# 38006     https://i.ytimg.com/vi/4Sx-D6aQ630/default.jpg             False
# 23136     https://i.ytimg.com/vi/r74rJC_5tYs/default.jpg             False
# 13780  https://i.ytimg.com/vi/8SAr4URIafA/default_liv...             False
# 31675     https://i.ytimg.com/vi/_hqzg37D_nU/default.jpg             False
# 42        https://i.ytimg.com/vi/t3FYESkzjUI/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 6424             False                  False
# 6436             False                  False
# 35825            False                  False
# 6454             False                  False
# 40622            False                  False
# ...                ...                    ...
# 38006            False                  False
# 23136            False                  False
# 13780            False                  False
# 31675            False                  False
# 42               False                  False
#
#                                              description country  \
# 6424   Ajit Pai has been at the heart of the net neut...      CA
# 6436   Federal regulators vote to allow Internet prov...      CA
# 35825  About This Is America: Women’s EditI thought i...      CA
# 6454             December 13, 2017 | Montgomery, Alabama      CA
# 40622  You don't just imagine a better future – you c...      CA
# ...                                                  ...     ...
# 38006  30 things went wrong from royal wedding Prince...      CA
# 23136  After the shocking Bachelor finale, Arie Luyen...      CA
# 13780                                                NaN      CA
# 31675                                                NaN      CA
# 42           Soul Machines is making machines more human      CA
#
#                                                     tags  category_id  \
# 6424   ,'thedc','dc','washington dc','washington','th...        804.0
# 6436   ,'fcc net neutrality','breaking news video','v...        102.0
# 35825  ,'nicole arbour','world's sexiest comedian','f...        806.0
# 6454                                           ,'[none]'        804.0
# 40622  ,'#pride','#proudtocreate','#proudtobe','#prou...        806.0
# ...                                                  ...          ...
# 38006  ,'royal weeding','michael bruce curry','gospel...        804.0
# 23136  ,'arie lauren exclusive interview','the bachel...        806.0
# 13780                                          ,'[none]'        804.0
# 31675  ,'toronto','north york','van','strike','canada...        804.0
# 42     ,'artificial intelligence','digital human','vi...        804.0
#
#        net_dislikes
# 6424       134575.0
# 6436       105839.0
# 35825       58311.0
# 6454        43472.0
# 40622       41836.0
# ...             ...
# 38006           9.0
# 23136           9.0
# 13780           6.0
# 31675           3.0
# 42              1.0
#
# [113 rows x 18 columns]

# %% [markdown]
# *The table above shows videos in CAN that had their dislikes more than their likes when they first appeared on the particular region's trending list - in total 113 videos*

# %% [markdown]
# # 3rd: The most common words in titles (CANADA)

# %%
new_can_df = can[can['title'].notnull()]

# %%
title_words_can = list(new_can_df['title'].apply(lambda x: x.split()))
title_words_can = [x for y in title_words_can for x in y]
Counter(title_words_can).most_common(30)
# Out:
# [('-', 12537),
#  ('|', 12519),
#  ('The', 5167),
#  ('2018', 3739),
#  ('the', 2617),
#  ('Episode', 2298),
#  ('&', 2287),
#  ('to', 2113),
#  ('in', 1848),
#  ('of', 1815),
#  ('and', 1769),
#  ('A', 1522),
#  ('on', 1407),
#  ('a', 1342),
#  ('To', 1316),
#  ('vs', 1260),
#  ('with', 1221),
#  ('2017', 1197),
#  ('Game', 1094),
#  ('Full', 1056),
#  ('2', 1024),
#  ('Trump', 962),
#  ('I', 938),
#  ('In', 930),
#  ('Official', 930),
#  ('Video)', 926),
#  ('You', 889),
#  ('With', 881),
#  ('10', 871),
#  ('New', 870)]

# %% [markdown]
# *We can see that in CANADA trending video titles symbols **"-"** and **"|"** occured the most: **12537** and **12519** times respectively. The most often words in tittles is **"The", "the"** and **"Episode"** - they appeared **5167, 2617 and 2298** times respectively.*

# %% [markdown]
# # 4th: What are the most common tags in each of the categories?

# %% [markdown]
# *First, check what's the most common tags in the hole dataset (CAN)*

# %%
new_can_df_tags = can[can['tags'].notnull()]

# %%
popular_tags_can = list(new_can_df_tags['tags'].apply(lambda x: x.split()))
popular_tags_can = [x for y in popular_tags_can for x in y]
Counter(popular_tags_can).most_common(30)
# Out:
# [('the', 6559),
#  ('of', 5431),
#  ('to', 5296),
#  ('and', 5092),
#  ('vs', 4378),
#  ('in', 4140),
#  ('new', 2871),
#  (",'[none]'", 2155),
#  ('a', 2151),
#  ('punjabi', 2065),
#  ('songs', 1940),
#  ('episode', 1885),
#  ('on', 1883),
#  ('with', 1760),
#  ('full', 1753),
#  ('for', 1675),
#  ('game', 1666),
#  ('tv', 1609),
#  ('season', 1555),
#  (",'the", 1346),
#  ('is', 1299),
#  ('you', 1231),
#  ('music', 1153),
#  ('&', 1150),
#  ('paul', 1115),
#  ('food', 1091),
#  ('not', 1079),
#  ('de', 1071),
#  ('latest', 1064),
#  ('voice', 955)]

# %% [markdown]
# # 5th: What are the relationship between the number of tags and the number of views? Does this relationship appears in all countries?

# %%
can['num_tags_can'] = can['tags'].astype(str).apply(lambda x: len(x.split(',')) if x != '[none]' else 0)

# %%
ax = can.plot(kind='scatter', x='num_tags_can', y='views', figsize=(14,8))
plot_configurations(ax, xlbl='Number of tags', ylbl='Number of views')

# %% [markdown]
# ## Relationship between description length and number of views

# %%
fig, ax_can = plt.subplots(figsize=(14,8))
sns.scatterplot(x=can['description'].str.len(), y=can['views'])
plot_configurations(ax, xlbl='Description length', ylbl='Number of views')

# %% [markdown]
# *Scatter Plot above displays similar relationship between number of views and lenght of description as it displayed in US dataset - the longer the video description, the lower the number of views. Only here in Canada there is **slighly more** videos with a long description, if we compaire with US. I will try to edit column 'num_tags' so I can visualize relationship between the number of tags and the number of views.*

# %% [markdown]
# ## Repeat all previous steps with Great Britain dataset

# %%
gb = pd.read_csv('GBvideos.csv', sep=';')
gb.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title              publish_time       views     likes  \
# 0                  John Lewis  2017-11-10T07:38:29.000Z   7224515.0   55681.0
# 1         Saturday Night Live  2017-11-12T06:24:44.000Z   1053632.0   25561.0
# 2                  EminemVEVO  2017-11-10T17:00:03.000Z  17158579.0  787420.0
# 3  Salford City Football Club  2017-11-13T02:30:38.000Z     27833.0     193.0
# 4            Cute Girl Videos  2017-11-13T01:45:13.000Z      9815.0      30.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0   10247.0         9479.0  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
# 1    2294.0         2757.0  https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg
# 2   43420.0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 3      12.0           37.0  https://i.ytimg.com/vi/PUTEiSjKwJU/default.jpg
# 4       2.0           30.0  https://i.ytimg.com/vi/rHwDegptbI4/default.jpg
#
#   comments_disabled ratings_disabled video_error_or_removed  \
# 0             False            False                  False
# 1             False            False                  False
# 2             False            False                  False
# 3             False            False                  False
# 4             False            False                  False
#
#                                          description country  \
# 0  Click here to continue the story and make your...      GB
# 1  Musical guest Taylor Swift performs …Ready for...      GB
# 2  Eminem's new track Walk on Water ft. Beyoncé i...      GB
# 3  Salford drew 4-4 against the Class of 92 and F...      GB
# 4  Dashcam captures truck's near miss with child ...      GB
#
#                                                 tags  category_id
# 0  ,'christmas','john lewis christmas','john lewi...          NaN
# 1  ,'snl','saturday night live','snl season 43','...        806.0
# 2  ,'eminem','walk','on','water','aftermath/shady...        600.0
# 3  ,'salford city fc','salford city','salford','c...        802.0
# 4                                          ,'[none]'        102.0

# %% [markdown]
# ### Shape of Great Britain Dataset

# %%
gb.shape
# Out:
# (42467, 17)

# %% [markdown]
# *GB Dataset consist of **42 467** rows and 17 columns.*

# %% [markdown]
# #### The names of all columns in this GB dataset

# %%
gb.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'publish_time',
#        'views', 'likes', 'dislikes', 'comment_count', 'thumbnail_link',
#        'comments_disabled', 'ratings_disabled', 'video_error_or_removed',
#        'description', 'country', 'tags', 'category_id'],
#       dtype='object')

# %% [markdown]
# #### Unique videos in a dataset

# %%
count_of_unique_videos_gb = gb['video_id'].unique().shape[0]
count_of_unique_videos_gb
# Out:
# 3417

# %% [markdown]
# *Great Britain dateset contains **3417** unique videos.*

# %% [markdown]
# ## Column Data types (GB)

# %%
gb.dtypes
# Out:
# video_id                   object
# trending_date              object
# title                      object
# channel_title              object
# publish_time               object
# views                     float64
# likes                     float64
# dislikes                  float64
# comment_count             float64
# thumbnail_link             object
# comments_disabled          object
# ratings_disabled           object
# video_error_or_removed     object
# description                object
# country                    object
# tags                       object
# category_id               float64
# dtype: object

# %%
column_datatypes_to_change_gb = ['views', 'likes', 'dislikes', 'comment_count']
for column in column_datatypes_to_change_gb:
    gb[column] = gb[column].astype(int)

# %%
gb['trending_date'] = pd.to_datetime(gb['trending_date'],errors='coerce', format='%y.%d.%m')
gb['publish_time'] = pd.to_datetime(gb['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# %%
gb.dtypes
# Out:
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# publish_time              datetime64[ns]
# views                              int32
# likes                              int32
# dislikes                           int32
# comment_count                      int32
# thumbnail_link                    object
# comments_disabled                 object
# ratings_disabled                  object
# video_error_or_removed            object
# description                       object
# country                           object
# tags                              object
# category_id                      float64
# dtype: object

# %% [markdown]
# ## Missing data (GB)

# %%
for i in gb.columns:
    null_rate_gb = gb[i].isna().sum()/len(gb)*100
    if null_rate >= 0:
        print("Column '{}' null rate: {}%".format(i,round(null_rate,2)))
# Out:
# Column 'video_id' null rate: 19.36%
# Column 'trending_date' null rate: 19.36%
# Column 'title' null rate: 19.36%
# Column 'channel_title' null rate: 19.36%
# Column 'publish_time' null rate: 19.36%
# Column 'views' null rate: 19.36%
# Column 'likes' null rate: 19.36%
# Column 'dislikes' null rate: 19.36%
# Column 'comment_count' null rate: 19.36%
# Column 'thumbnail_link' null rate: 19.36%
# Column 'comments_disabled' null rate: 19.36%
# Column 'ratings_disabled' null rate: 19.36%
# Column 'video_error_or_removed' null rate: 19.36%
# Column 'description' null rate: 19.36%
# Column 'country' null rate: 19.36%
# Column 'tags' null rate: 19.36%
# Column 'category_id' null rate: 19.36%

# %% [markdown]
# *All columns in GB Dataset has the same level of missing values - almost the **fifth part** is missing (19,36%).*

# %%
gb.isnull().sum()
# Out:
# video_id                     0
# trending_date             3661
# title                     2948
# channel_title             3012
# publish_time              3661
# views                     3661
# likes                     3661
# dislikes                  3661
# comment_count             3661
# thumbnail_link            3661
# comments_disabled         3661
# ratings_disabled          3661
# video_error_or_removed    3661
# description               4273
# country                   4374
# tags                      4374
# category_id               5202
# dtype: int64

# %% [markdown]
# *We can see that all columns **(except 'video_id')** contains couple thousands of NULL values. There are no 1 right way to deal with them.*

# %% [markdown]
# *Get rid of missing values in columns **Views**, **Likes,** **Dislikes** and **Comment_count** to do analysis with them. We could replace missing values with average values in each column, but this time I think we can replace NaN values with 0 as well.*

# %%
gb['views'] = gb['views'].fillna(0)
gb['likes'] = gb['likes'].fillna(0)
gb['dislikes'] = gb['dislikes'].fillna(0)
gb['comment_count'] = gb['comment_count'].fillna(0)

# %%
gb.isnull().sum()
# Out:
# video_id                     0
# trending_date             3661
# title                     2948
# channel_title             3012
# publish_time              3661
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link            3661
# comments_disabled         3661
# ratings_disabled          3661
# video_error_or_removed    3661
# description               4273
# country                   4374
# tags                      4374
# category_id               5202
# dtype: int64

# %% [markdown]
# *Now neither of the mentioned columns has NULL values.*

# %% [markdown]
# ### Disabled Comments, Ratings & Errors

# %%
gb["video_error_or_removed"].value_counts()
# Out:
# False    38737
# True        69
# Name: video_error_or_removed, dtype: int64

# %% [markdown]
# *Out of videos that had a information about this variable (38 806) only 69 videos had errors or they were removed.*

# %%
gb["comments_disabled"].value_counts()
# Out:
# False    38172
# True       634
# Name: comments_disabled, dtype: int64

# %% [markdown]
# *Only **634** videos had their comments disabled which is 1,5% of all videos that had info about this variable (as seen in code below).*

# %%
gb["ratings_disabled"].value_counts()
# Out:
# False    38596
# True       210
# Name: ratings_disabled, dtype: int64

# %% [markdown]
# *Once again, only a small portion **(210)** of all videos had their ratings disabled.*

# %% [markdown]
# #### Videos that remained the most on trending video list (GB)

# %%
gb['title'].value_counts().head(20)
# Out:
# Maroon 5 - Wait                                                                              40
# Justin Timberlake’s FULL Pepsi Super Bowl LII Halftime Show! | NFL Highlights                38
# Anne-Marie - 2002 [Official Video]                                                           38
# Jurassic World: Fallen Kingdom - Official Trailer #2 [HD]                                    38
# To Our Daughter                                                                              38
# Rich Brian - Cold (Official Music Video)                                                     37
# Fergie Performs The U.S. National Anthem / 2018 NBA All-Star Game                            37
# BHAD BHABIE feat. Lil Yachty - Gucci Flip Flops (Official Music Video) | Danielle Bregoli    37
# Sam Smith - Pray (Official Video) ft. Logic                                                  37
# Royce da 5'9 - Caterpillar ft. Eminem, King Green                                            37
# Enrique Iglesias - MOVE TO MIAMI (Official Video) ft. Pitbull                                37
# Janelle Monáe – Make Me Feel [Official Music Video]                                          37
# Incredibles 2 - Olympics Sneak Peek                                                          37
# Whethan, Dua Lipa - High (Audio)                                                             37
# Florence + The Machine - Hunger                                                              37
# VENOM - Official Teaser Trailer (HD)                                                         37
# Karol G - Pineapple                                                                          36
# Mason Ramsey - Famous [Lyric Video]                                                          36
# Pawn Stars: Dana White Wants Rick's 1600s Japanese Katana (Season 15) | History              36
# kanye west / charlamagne interview                                                           36
# Name: title, dtype: int64

# %% [markdown]
# *Table above shows that in the Great Britain's dataset video that remained the most on trending video list is called **"Maroon 5 - Wait",** it appeared on the list **40** times, which means that this video appeared on the trending video list the most times compared to all other videos in these 3 datasets.*

# %% [markdown]
# ## Top Categories (GB)

# %%
gb['category_id'].value_counts().head(120)
# Out:
# 600.0    13715
# 806.0     8875
# 804.0     2864
# 201.0     1886
# 803.0     1788
# 805.0     1776
# 802.0     1670
# 102.0     1225
# 202.0      629
# 301.0      506
# 700.0      491
# 302.0      457
# 801.0      141
# 101.0       90
# 402.0       86
# 410.0       77
# 412.0       71
# 407.0       69
# 415.0       68
# 403.0       68
# 414.0       66
# 418.0       53
# 408.0       49
# 424.0       45
# 420.0       36
# 419.0       35
# 416.0       32
# 426.0       28
# 411.0       28
# 504.0       22
# 440.0       21
# 204.0       20
# 441.0       20
# 507.0       18
# 409.0       18
# 417.0       16
# 406.0       14
# 514.0       13
# 413.0       12
# 452.0       12
# 423.0       12
# 446.0       12
# 430.0       11
# 516.0       11
# 448.0       10
# 456.0       10
# 458.0       10
# 460.0       10
# 453.0        9
# 511.0        9
# 467.0        8
# 437.0        8
# 524.0        7
# 520.0        6
# 525.0        6
# 470.0        6
# 532.0        4
# 482.0        3
# 428.0        3
# Name: category_id, dtype: int64

# %%
# Based on data that is found in categories.csv we can found out the distribution of videos by Categories

politics = gb.loc[(gb.category_id >= 100) & (gb.category_id <= 102)].count()[0]
cinema = gb.loc[(gb.category_id >= 200) & (gb.category_id <= 204)].count()[0]
education = gb.loc[(gb.category_id >= 300) & (gb.category_id <= 302)].count()[0]
diy_and_beauty = gb.loc[(gb.category_id >= 400) & (gb.category_id <= 497)].count()[0]
travel_and_events = gb.loc[(gb.category_id >= 500) & (gb.category_id <= 551)].count()[0]
music = gb.loc[(gb.category_id >= 600) & (gb.category_id <= 600)].count()[0]
animals = gb.loc[(gb.category_id >= 700) & (gb.category_id <= 700)].count()[0]
entertainment = gb.loc[(gb.category_id >= 800) & (gb.category_id <= 806)].count()[0]

categories = [politics, cinema, education, diy_and_beauty, travel_and_events, music, animals, entertainment]
explode = [0,0,0,0,.25,0,0,0]
colors = ['magenta', 'cyan', 'pink', 'salmon', 'khaki', 'lightblue', 'lightgreen', 'orange']
labels = ['Politics', 'Cinema', 'Education', 'DIY&Beauty', 'Travel&Events', 'Music', 'Animals', 'Entertainment']

#plt.title('Distribution of videos by Categories!')

plt.pie(categories, labels=labels, radius=3, colors=colors, autopct='%.2f %%', pctdistance=0.8, explode=explode)
plt.show()

# %% [markdown]
# *In the Pie Chart above we see that when looking at Great Britain dateset Entertainment category contains the largest number of trending videos among other categories **(45,93%)**, followed by Music category **(36,80%)**, followed by Cinema category **(6,80%)**, and so on.*

# %% [markdown]
# ## Views of the videos (GB)

# %% [markdown]
# #### A trending video with the fewest views (excluding those with 0 views)

# %%
unique_videos_gb_least_views = (gb[gb['views'] > 0].sort_values(by='views', ascending=True)).drop_duplicates(subset=['video_id']).head(1)
unique_videos_gb_least_views
# Out:
#          video_id trending_date  \
# 4111  n26wtR-OFr8    2017-12-01
#
#                                                   title     channel_title  \
# 4111  Mountain Bikers Worried About Military Land Be...  That's Surrey TV
#
#             publish_time  views  likes  dislikes  comment_count  \
# 4111 2017-11-27 18:08:49  851.0   12.0       0.0            3.0
#
#                                       thumbnail_link comments_disabled  \
# 4111  https://i.ytimg.com/vi/n26wtR-OFr8/default.jpg             False
#
#      ratings_disabled video_error_or_removed  \
# 4111            False                  False
#
#                                             description country  \
# 4111  A group of mountain bikers are concerned that ...      GB
#
#                                                    tags  category_id
# 4111  ,'surrey','that's tv','that's surrey','mountai...        102.0

# %% [markdown]
# *Video with the LEAST views is called **"Mountain Bikers Worried About Military Land Be..."** from channel "That's Surrey TV" which had accumulated 851 views.*

# %% [markdown]
# ##### TOP 5 trending videos with the LEAST Views - excluding those with 0 views

# %%
unique_videos_gb_least_views = (gb[gb['views'] > 0].sort_values(by='views', ascending=True)).drop_duplicates(subset=['video_id']).head(5)
unique_videos_gb_least_views
# Out:
#          video_id trending_date  \
# 4111  n26wtR-OFr8    2017-12-01
# 5390  vPsic3dEndc    2017-12-07
# 280   NcVxrr_q3Hw    2017-11-15
# 7522  BsQZPKeaKBg    2017-12-17
# 7947  B1tEq5RU-Wo    2017-12-19
#
#                                                   title  \
# 4111  Mountain Bikers Worried About Military Land Be...
# 5390        QUIZ : Name the Trail : A Christmas Cracker
# 280   George Durack | Remembrance Sunday | You Can't...
# 7522  1080p WOLF OF THE AUTOSTRADA - RUF Automobile ...
# 7947                Best bikes in the world: Cotic Soul
#
#                        channel_title        publish_time   views  likes  \
# 4111                That's Surrey TV 2017-11-27 18:08:49   851.0   12.0
# 5390               The 2Inch of Gnar 2017-12-01 11:34:30  1184.0    2.0
# 280   Official Jeremy Corbyn Channel 2017-11-12 07:37:46  1505.0   88.0
# 7522                    VirusTornado 2017-12-13 20:08:02  1858.0   61.0
# 7947                    Guy Kesteven 2017-12-15 20:51:50  1930.0   54.0
#
#       dislikes  comment_count                                  thumbnail_link  \
# 4111       0.0            3.0  https://i.ytimg.com/vi/n26wtR-OFr8/default.jpg
# 5390       0.0            1.0  https://i.ytimg.com/vi/vPsic3dEndc/default.jpg
# 280       12.0           40.0  https://i.ytimg.com/vi/NcVxrr_q3Hw/default.jpg
# 7522       1.0           13.0  https://i.ytimg.com/vi/BsQZPKeaKBg/default.jpg
# 7947       0.0           24.0  https://i.ytimg.com/vi/B1tEq5RU-Wo/default.jpg
#
#      comments_disabled ratings_disabled video_error_or_removed  \
# 4111             False            False                  False
# 5390             False            False                  False
# 280              False            False                  False
# 7522             False            False                  False
# 7947             False            False                  False
#
#                                             description country  \
# 4111  A group of mountain bikers are concerned that ...      GB
# 5390  A Bad Brains Christmas Cracker! - #NameTheTrai...      GB
# 280   Ahead of Remembrance Sunday, I visited my frie...      GB
# 7522  FULL HD VERSION\n\nFeaturing Valentino Balboni...      GB
# 7947  #sponsored Full live ride reviews of the lates...      GB
#
#                                                    tags  category_id
# 4111  ,'surrey','that's tv','that's surrey','mountai...        102.0
# 5390  ,'mtb','mountain biking','bike','bird','aeris'...        804.0
# 280                                           ,'[none]'          NaN
# 7522  ,'ruf','porsche','ctr','yellowbird','911','car...        801.0
# 7947  ,'imovie','mountain bike','mountain biking','s...        802.0

# %% [markdown]
# #### A trending video with the maximum number of views

# %%
gb[gb['views'] == gb['views'].max()].transpose()
# Out:
#                                                                     30683
# video_id                                                      _I_D_8Z4sJE
# trending_date                                         2018-04-07 00:00:00
# title                   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
# channel_title                                                  NickyJamTV
# publish_time                                          2018-03-02 05:00:19
# views                                                         4.24539e+08
# likes                                                         2.81877e+06
# dislikes                                                           149275
# comment_count                                                       99380
# thumbnail_link             https://i.ytimg.com/vi/_I_D_8Z4sJE/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             Disponible en tu plataforma preferida:\nhttps:...
# country                                                                GB
# tags                    ,'bad bunny','amorfoda','dura','daddy yankee',...
# category_id                                                           600

# %%
gb['views'].max()
# Out:
# 424538912.0

# %% [markdown]
# *In Great Britain video with the **MOST** views is called **"Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic..."** from channel "NickyJamTV" which had accumulated more than 424 million views.*

# %% [markdown]
# #### TOP 5 videos with the MOST Views

# %%
unique_videos_gb_most_views = gb.sort_values(by='views', ascending=False).drop_duplicates(subset=['video_id'])
unique_videos_gb_most_views[['title', 'views']].head(5)
# Out:
#                                                    title      views
# 30683  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912
# 37799  Te Bote Remix - Casper, Nio García, Darell, Ni...  337621571
# 27677               Bad Bunny - Amorfoda | Video Oficial  328860380
# 23107           Ozuna x Romeo Santos - El Farsante Remix  288811992
# 41941  Childish Gambino - This Is America (Official V...  259721696

# %% [markdown]
# ## The most Likes, Comments, Dislikes and Views (GB)

# %%
def visualize_most(gb, column, num=10):
    sorted_df_gb = gb.sort_values(column, ascending=False).iloc[:num]
    
    ax = sorted_df_gb[column].plot.bar()
    
    # customizes the video titles, for asthetic purposes for the bar chart
    labels = []
    for item in sorted_df_gb['title']:
        labels.append(item[:12] + '...')
    ax.set_xticklabels(labels, rotation=45, fontsize=10)
    
    plt.show()

# %% [markdown]
# *Before we pass into the function column names to found out the results, we can sort dataset and store it in a new variable without any dublicates.*

# %%
without_dublicates_gb = gb.drop_duplicates(subset=['video_id'])

# %%
visualize_most(without_dublicates_gb, 'comment_count')

# %%
visualize_most(without_dublicates_gb, 'dislikes')

# %%
visualize_most(without_dublicates_gb, 'likes')

# %%
visualize_most(unique_videos_gb_most_views, 'views')

# %% [markdown]
# *In order to answer to 2nd question, we can include all videos from each region, even dublicates because each time the video appears in dataset represent the each time it became trendy.*

# %%
visualize_most(gb, 'views', num=15)

# %%
visualize_most(gb, 'comment_count', num=15)

# %%
visualize_most(gb, 'dislikes', num=15)

# %%
visualize_most(gb, 'likes', num=15)

# %% [markdown]
# ## Most Popular Trending Channels (GB)

# %%
gb.groupby(['channel_title']).size().sort_values(ascending=False).head(12)
# Out:
# channel_title
# 806                                       249
# 802                                       237
# The Tonight Show Starring Jimmy Fallon    208
# Jimmy Kimmel Live                         207
# TheEllenShow                              207
# Saturday Night Live                       206
# WWE                                       205
# The Late Late Show with James Corden      202
# Late Night with Seth Meyers               194
# Breakfast Club Power 105.1 FM             193
# The Late Show with Stephen Colbert        189
# Netflix                                   187
# dtype: int64

# %%
trending_channels_gb = gb.groupby(['channel_title']).size().sort_values(ascending=False).head(12)
sns.barplot(trending_channels_gb.values, trending_channels_gb.index.values, palette = 'viridis')
plt.title('Top 10 Trending Channels in GB')
plt.xlabel('Video Count')
plt.show()
#Again, in results I got some mysterious channel '806' and '802' that dont exist, so I ignore them.
# Out:
# C:\Users\username\Downloads\Programs\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# *We can conclude that in Great Britain dominates **talk-show** channels like "The Tonight Show Starring Jimmy Fallon", "Jimmy Kimmel Live", "The EllenShow" and others. TOP 10 also entered by WWE that offers original shows and exclusives.*

# %% [markdown]
# ### Most Popular Publishing Day & Time (GB)

# %%
gb['day_published'] = gb['publish_time'].dt.day_name()
gb['hour_published'] = gb['publish_time'].dt.hour

# %%
ax = gb['day_published'].value_counts().plot(
    kind='bar', figsize=(10,6), rot=0)

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.tight_layout()

# %% [markdown]
# *As seen in table above, the most trending videos in Great Britain was published in **working days** (just like in Canada and USA) - Monday, Thursday, Tuesday, Wednesday and Friday, with Friday having the highest number of trending videos than the rest of working days. But on holidays as it was expected there were significantly less publishing of trending videos.*

# %% [markdown]
# ### Most Popular Publishing Hour (GB)

# %%
ax_gb = gb['hour_published'].value_counts().sort_index().plot(
    kind='bar', figsize=(14,8), rot=0)

ax_can.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.tight_layout()

# %% [markdown]
# *Here we can see very similar picture to what we saw previously in other regions. The most trending videos in Great Britain was published in the afternoon, gaining rapid increase at 1:00 p.m and reaching the maximum at 5 p.m., while early morning hours (6:00 a.m. - 8.00 a.m) is the time when you dont want to publish a video if you want it to go viral.*

# %% [markdown]
# ### Correlations (GB)

# %%
columns_needed_gb = ['views', 'likes', 'dislikes', 'comment_count'] # only these columns needed this time
corr_matrix_gb = gb[columns_needed_can].corr()
corr_matrix_gb
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.797739  0.394342       0.470436
# likes          0.797739  1.000000  0.448368       0.745987
# dislikes       0.394342  0.448368  1.000000       0.772125
# comment_count  0.470436  0.745987  0.772125       1.000000

# %%
gb['like_dislike_ratio'] = gb['likes'] / gb['dislikes']
gb['comments_percentage'] = gb['comment_count'] / gb['views']
gb['reaction_percentage'] = (gb['likes'] + gb['dislikes']) / gb['views']

# %%
correlation_gb = gb[['views', 'likes', 'dislikes', 'comment_count', 'like_dislike_ratio', 'comments_percentage', 'reaction_percentage']]
corr_gb = correlation.corr()

mask_gb = np.zeros_like(corr_gb, dtype=np.bool)
mask_gb[np.triu_indices_from(mask_gb)] = True

cmap_gb = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr_gb, mask=mask_gb, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# *Matrix above shows that there are several moderate correlations. Just like we saw previously in USA and Canada dataset, also in this Great Britain dataset most noticable correlation is comment count is positevely related with views, likes and dislikes. That means that people who react with a like or dislike are also more likely leave a comment after watching the video.*

# %% [markdown]
# # ADDITIONAL TASKS (GB):

# %% [markdown]
# ## 1st: How many comments a video has when first appearing on the trending list?

# %%
gb_without_d = gb.drop_duplicates(subset=['video_id'])
ax_gb = gb_without_d['comment_count'].plot(kind='hist', figsize=(14,8), lw=1, ec='lightgray',
                               bins=np.arange(0, 2.6e6, 5e4)-0.5, 
                               logy=True)

plot_configurations(ax_gb, xlbl='Number of comments', ylbl='Number of videos', ticklbl_size=11, lbl_size=12)
formatter = ticker.FuncFormatter(func=lambda x,y: '{:.0f}K'.format(x/1e3))
ax.xaxis.set_major_locator(ticker.MultipleLocator(200000))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatter));
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter(fmt='{x:,.0f}'))
plt.tight_layout()

# %%
gb_without_d['comment_count'].describe().apply(lambda x: format(x, 'f'))
# Out:
# count      3266.000000
# mean       6382.446724
# std       28423.166306
# min           0.000000
# 25%         324.000000
# 50%        1026.000000
# 75%        3675.750000
# max      733371.000000
# Name: comment_count, dtype: object

# %%
'{:,.0f}'.format(gb_without_d[gb_without_d['comment_count'] != 0]['comment_count'].min())
# Out:
# '1'

# %%
gb_without_d[gb_without_d['comment_count'] == 1]
# Out:
#           video_id trending_date  \
# 4120   xF9kTkjrHdQ      17.01.12
# 5390   vPsic3dEndc      17.07.12
# 7086   sVfTvLm-7Ac      17.15.12
# 15819  yo8cCV0_zCg      18.26.01
#
#                                                    title      channel_title  \
# 4120                       Roberto Carlos vs France 1997              Saint
# 5390         QUIZ : Name the Trail : A Christmas Cracker  The 2Inch of Gnar
# 7086      HIGHLIGHTS: MK Dons U18s 1-0 Cardiff City U18s            MK Dons
# 15819  Maisie Williams is going to be Game of Thrones...        Radio Times
#
#                    publish_time    views  likes  dislikes  comment_count  \
# 4120   2011-02-03T14:07:55.000Z  63535.0    9.0       0.0            1.0
# 5390   2017-12-01T11:34:30.000Z   1184.0    2.0       0.0            1.0
# 7086   2017-12-13T16:33:57.000Z  11290.0   22.0       0.0            1.0
# 15819  2018-01-21T20:00:03.000Z  29020.0   38.0       0.0            1.0
#
#                                        thumbnail_link comments_disabled  \
# 4120   https://i.ytimg.com/vi/xF9kTkjrHdQ/default.jpg             False
# 5390   https://i.ytimg.com/vi/vPsic3dEndc/default.jpg             False
# 7086   https://i.ytimg.com/vi/sVfTvLm-7Ac/default.jpg             False
# 15819  https://i.ytimg.com/vi/yo8cCV0_zCg/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 4120             False                  False
# 5390             False                  False
# 7086             False                  False
# 15819            False                  False
#
#                                              description country  \
# 4120                                                          GB
# 5390   A Bad Brains Christmas Cracker! - #NameTheTrai...      GB
# 7086   Check out Tommy Hope's stunning winner in the ...      GB
# 15819  The Early Man actress reveals she will play a ...      GB
#
#                                                     tags  category_id
# 4120                                      ,'536282c','1'        802.0
# 5390   ,'mtb','mountain biking','bike','bird','aeris'...        804.0
# 7086              ,'tommy hope','mk dons','cardiff city'        802.0
# 15819  ,'maisie williams','sophie turner','joe jonas'...        806.0

# %% [markdown]
# *These are the videos **(4 in total)** in GB's trending list that have the lowesst number of comments (1) when they first appeared on trending list*

# %% [markdown]
# ## 2nd: How many videos in each country that had their Dislikes more than their Likes when first appeared on the trending list (GB)?

# %% [markdown]
# gb_without_d = gb.drop_duplicates(subset=['video_id'])

# %%
gb_without_d['net_dislikes'] = (gb_without_d['dislikes'] - gb_without_d['likes'])
gb_without_d[gb_without_d['net_dislikes'] > 0].sort_values(by='net_dislikes', ascending=False)
# Out:
# <ipython-input-31-deef8e66fe90>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gb_without_d['net_dislikes'] = (gb_without_d['dislikes'] - gb_without_d['likes'])
#           video_id trending_date  \
# 7034   LFhT6H6pRWg      17.15.12
# 37098  QW8whgmyTNU      18.15.05
# 7274   8I_NkJ8VTEI      17.16.12
# 18842  IPgdIHV_zMo      18.10.02
# 14680  2B85lYenaxE      18.21.01
# 20791  V5cOvyDpWfM      18.19.02
# 16493  Ct_lrDNvxoA      18.29.01
# 18004  SlbY1tGARUA      18.06.02
# 21649  l8B5dqjsZUs      18.23.02
# 37097  9flG5EqRPSc      18.15.05
# 7075   tT-lTxhW7pY      17.15.12
# 14402  p4HrpCPquk4      18.19.01
# 2843   qu-biRtYEcU      17.26.11
# 15554  JwfZqomlPsk      18.25.01
# 6590   lYEj9snU838      17.13.12
# 36562  Os4MTTzTKRo      18.12.05
# 15311  e2ExvdtmIyU      18.24.01
# 13558  RAXo1Y7AK_I      18.16.01
# 17013  FwzoDS3zL_4      18.01.02
# 36191  Ub3ot5DC_iE      18.10.05
# 42134  DVWxQvlgRrM      18.13.06
# 27883  j1oMVG1ZMlA      18.25.03
# 14229  II-OP6vdMs8      18.19.01
# 31129  mjtn3EEG65Q      18.16.04
# 22272  CBZgoICDr6E      18.26.02
# 34291  NclJj1h_MW4      18.30.04
# 8514   pNpsjMnO7mU      17.22.12
# 31564  1x_5E3gquFo      18.18.04
# 4875   Vlv_rWiwp-0      17.05.12
# 16530  i7FgneNlM14      18.30.01
# 13369  SHI6LfICx6k      18.15.01
# 30760  xzWDIgvsFTY      18.14.04
# 30755  TvLGiAbgRc4      18.14.04
# 4148   S91qCkeiu3U      17.01.12
# 7326   WHzTLDP4o_Q      17.16.12
# 11537  -tjucPZlcgc      18.05.01
# 13624  eT9eWtb7C4c      18.16.01
# 14293  oJ_g5fUxtQo      18.19.01
# 178    S0A4hBJHND4      17.14.11
# 12001  kQQZ2hje42E      18.07.01
# 8310   d5w7iCkHvaU      17.21.12
# 13559  9Jn8TXoPQTg      18.16.01
# 16137  3QeRZj3LhS4      18.28.01
# 105    _wM_jY_rass      17.14.11
# 127    l9nGCJlDclQ      17.14.11
#
#                                                    title  \
# 7034               PSA from Chairman of the FCC Ajit Pai
# 37098                      This Is America: Women's Edit
# 7274                  Judge Roy Moore Campaign Statement
# 18842     I Feel Pretty Trailer #1 | Movieclips Trailers
# 14680  Heathers Official Red Band Trailer | Premieres...
# 20791  Fergie Performs The U.S. National Anthem / 201...
# 16493  HEATHERS Official Trailer (2018) Comedy TV Sho...
# 18004  Official Ram Trucks Super Bowl Commercial | Dr...
# 21649         Reboot: The Guardian Code Official Trailer
# 37097  Netta (Israel 'Toy') wins Eurovision after dra...
# 7075   Roy Moore Delivers Concession Speech From Alab...
# 14402  Teen Titans GO! To The Movies - Official Tease...
# 2843                                 Volar - Jaime Ciero
# 15554         RollerCoaster Tycoon Start Engine Campaign
# 6590   Boy speaks out on viral bullying video, mom ad...
# 36562      Amy Schumer Is Ready to Host the Best SNL Yet
# 15311  The Breakfast Club Addresses Backlash After Am...
# 13558                    Chelsea Manning for U.S. Senate
# 17013              KFC | Honky Tonk | Smoky Mountain BBQ
# 36191          Amy Schumer Goes Behind the Scenes at SNL
# 42134     Robert De Niro - F--- Trump - 2018 Tony Awards
# 27883               March For Our Lives - Washington, DC
# 14229  #MeToo Backlash | January 17, 2018 Act 1 | Ful...
# 31129                           Billy Mitchell Statement
# 22272  When you see that your ex has moved onDota2(Na...
# 34291   Watch Michelle Wolf roast Sarah Huckabee Sanders
# 8514   Jason Whitlock weighs in on LaVar Ball's idea ...
# 31564  Dwyane Wade Trash Talks Allen Iverson and Kevi...
# 4875   DAY 4: Kendall Jenner by Phil Poynter #LOVEADV...
# 16530  WEEI: Alex Reimer calls Tom Brady’s daughter a...
# 13369                         Kyle Meredith with... Moby
# 30760  Ray Borg Reflects On Conor McGregor’s Bus Atta...
# 30755  Blac Chyna Designs a Dream House That Has a 10...
# 4148   Paige VanZant Confirms Jan. 14 fight in St. Lo...
# 7326   Woody Woodpecker - Trailer - Own it 2/6 on DVD...
# 11537                     F&F Active | #whatsstoppingyou
# 13624  Show Dogs | Official Trailer | In Theaters May 18
# 14293  BLAKE GRIFFIN AND CHRIS PAUL FIGHT COMPILATION...
# 178    Svjetska ekskluziva: Provala u stan Dejana Lov...
# 12001         Cooking With Your Mouth | Christmas Turkey
# 8310   Darya Folsom and caller LAUGH! at diddy move t...
# 13559                                     The Gravy Mary
# 16137       The Coworker | #ThatsHarassment | Ad Council
# 105                                    Bone on Labour HQ
# 127    After Show: Did Kate Hudson Date Brad Pitt? | ...
#
#                                       channel_title              publish_time  \
# 7034                                   Daily Caller  2017-12-13T22:52:57.000Z
# 37098                                 Nicole Arbour  2018-05-12T22:42:24.000Z
# 7274                           Roy Moore for Senate  2017-12-14T03:04:05.000Z
# 18842                           Movieclips Trailers  2018-02-08T20:00:03.000Z
# 14680                             Paramount Network  2018-01-18T20:12:56.000Z
# 20791                                MLG Highlights  2018-02-19T01:37:11.000Z
# 16493                                 Rapid Trailer  2018-01-18T18:44:03.000Z
# 18004                                    Ram Trucks  2018-02-05T00:45:18.000Z
# 21649                     ReBoot: The Guardian Code  2018-02-22T00:54:24.000Z
# 37097                                           BBC  2018-05-12T23:48:30.000Z
# 7075                                       NBC News  2017-12-13T04:37:41.000Z
# 14402                         Warner Bros. Pictures  2018-01-10T18:00:16.000Z
# 2843                                     paulitaale  2011-12-26T02:50:18.000Z
# 15554                          RollerCoaster Tycoon  2018-01-23T18:02:51.000Z
# 6590                               CBS This Morning  2017-12-12T12:58:41.000Z
# 36562                           Saturday Night Live  2018-05-11T13:00:04.000Z
# 15311                 Breakfast Club Power 105.1 FM  2018-01-23T13:48:31.000Z
# 13558                               Chelsea Manning  2018-01-14T13:20:13.000Z
# 17013                                           KFC  2018-01-26T01:08:37.000Z
# 36191                           Saturday Night Live  2018-05-09T13:00:06.000Z
# 42134                                       Variety  2018-06-11T03:01:32.000Z
# 27883                           March For Our Lives  2018-03-24T20:15:07.000Z
# 14229                Full Frontal with Samantha Bee  2018-01-18T07:00:01.000Z
# 31129                                   Ryan Burger  2018-04-15T19:57:15.000Z
# 22272                                         Simon  2018-02-25T18:51:38.000Z
# 34291                                      NBC News  2018-04-29T05:29:27.000Z
# 8514   Speak For Yourself with Cowherd and Whitlock  2017-12-20T23:42:53.000Z
# 31564                                CliveNBAParody  2018-04-17T05:17:41.000Z
# 4875                       LOVE TV by LOVE Magazine  2017-12-04T08:23:17.000Z
# 16530                                    Nick Ramos  2018-01-27T04:20:20.000Z
# 13369                                 Kyle Meredith  2018-01-10T22:37:49.000Z
# 30760                              MMAFightingonSBN  2018-04-11T13:56:26.000Z
# 30755                          Architectural Digest  2018-04-10T16:00:31.000Z
# 4148                               MMAFightingonSBN  2017-11-28T05:12:54.000Z
# 7326          Universal Pictures Home Entertainment  2017-12-13T19:00:02.000Z
# 11537                                  F&F Clothing  2018-01-01T11:34:32.000Z
# 13624                               Open Road Films  2018-01-11T23:10:38.000Z
# 14293                                       Im Pops  2018-01-16T06:39:52.000Z
# 178                                   Jutarnji list  2017-11-03T12:30:24.000Z
# 12001                                      Nathan C  2017-12-23T00:23:13.000Z
# 8310                              Peter Parker Tube  2017-12-18T20:57:53.000Z
# 13559                            KFC UK and Ireland  2018-01-14T17:04:08.000Z
# 16137                                    Ad Council  2018-01-22T13:44:59.000Z
# 105                                   Ross Kempsell  2017-11-06T16:12:58.000Z
# 127         Watch What Happens Live with Andy Cohen  2017-11-08T17:00:01.000Z
#
#            views    likes  dislikes  comment_count  \
# 7034    649781.0   5505.0  140077.0        16730.0
# 37098   868163.0  17644.0   75955.0            0.0
# 7274    708489.0   3960.0   54062.0            0.0
# 18842   465667.0   6310.0   22568.0         5221.0
# 14680   798716.0   6927.0   22254.0         4839.0
# 20791  1211176.0   3551.0   18199.0         8338.0
# 16493   257727.0   2577.0   13707.0         3624.0
# 18004  1865148.0   4223.0    9681.0         2959.0
# 21649   140413.0    436.0    5630.0         2306.0
# 37097  4411085.0  32279.0   37318.0        19682.0
# 7075    194417.0    603.0    4732.0            0.0
# 14402  1121798.0   6600.0   10300.0         5013.0
# 2843   1213682.0    757.0    3275.0         1495.0
# 15554    27754.0     88.0    2458.0          595.0
# 6590    317143.0   2306.0    4508.0         3766.0
# 36562    51246.0    785.0    2772.0          613.0
# 15311   236711.0   2078.0    3532.0         3909.0
# 13558   245706.0   1701.0    3111.0         2009.0
# 17013   804049.0   4266.0    5624.0         2570.0
# 36191    75689.0   1158.0    2101.0          689.0
# 42134   453086.0   2899.0    3837.0         4404.0
# 27883   115931.0   5157.0    6089.0         2066.0
# 14229   635686.0  11383.0   12122.0         4289.0
# 31129    34446.0    124.0     696.0          359.0
# 22272    71850.0    593.0    1049.0          320.0
# 34291   337239.0   2650.0    3091.0         3185.0
# 8514     34209.0    337.0     697.0          565.0
# 31564    84152.0    666.0     979.0          233.0
# 4875    108094.0    306.0     604.0          179.0
# 16530   994747.0    258.0     398.0          629.0
# 13369    51516.0     84.0     211.0          335.0
# 30760    22388.0    247.0     365.0          517.0
# 30755    51951.0    625.0     738.0          394.0
# 4148      6097.0     64.0     135.0           97.0
# 7326     18364.0     66.0     109.0           25.0
# 11537     2414.0      5.0      43.0            9.0
# 13624  1482178.0     54.0      86.0           37.0
# 14293   236390.0    378.0     407.0          145.0
# 178      83794.0     83.0     108.0           74.0
# 12001    52871.0    224.0     245.0          139.0
# 8310     36343.0     17.0      36.0           29.0
# 13559     9503.0     88.0     101.0           73.0
# 16137   102631.0     76.0      88.0           21.0
# 105     159065.0   1160.0    1164.0            0.0
# 127      53253.0    184.0     187.0           83.0
#
#                                        thumbnail_link comments_disabled  \
# 7034   https://i.ytimg.com/vi/LFhT6H6pRWg/default.jpg             False
# 37098  https://i.ytimg.com/vi/QW8whgmyTNU/default.jpg              True
# 7274   https://i.ytimg.com/vi/8I_NkJ8VTEI/default.jpg              True
# 18842  https://i.ytimg.com/vi/IPgdIHV_zMo/default.jpg             False
# 14680  https://i.ytimg.com/vi/2B85lYenaxE/default.jpg             False
# 20791  https://i.ytimg.com/vi/V5cOvyDpWfM/default.jpg             False
# 16493  https://i.ytimg.com/vi/Ct_lrDNvxoA/default.jpg             False
# 18004  https://i.ytimg.com/vi/SlbY1tGARUA/default.jpg             False
# 21649  https://i.ytimg.com/vi/l8B5dqjsZUs/default.jpg             False
# 37097  https://i.ytimg.com/vi/9flG5EqRPSc/default.jpg             False
# 7075   https://i.ytimg.com/vi/tT-lTxhW7pY/default.jpg              True
# 14402  https://i.ytimg.com/vi/p4HrpCPquk4/default.jpg             False
# 2843   https://i.ytimg.com/vi/qu-biRtYEcU/default.jpg             False
# 15554  https://i.ytimg.com/vi/JwfZqomlPsk/default.jpg             False
# 6590   https://i.ytimg.com/vi/lYEj9snU838/default.jpg             False
# 36562  https://i.ytimg.com/vi/Os4MTTzTKRo/default.jpg             False
# 15311  https://i.ytimg.com/vi/e2ExvdtmIyU/default.jpg             False
# 13558  https://i.ytimg.com/vi/RAXo1Y7AK_I/default.jpg             False
# 17013  https://i.ytimg.com/vi/FwzoDS3zL_4/default.jpg             False
# 36191  https://i.ytimg.com/vi/Ub3ot5DC_iE/default.jpg             False
# 42134  https://i.ytimg.com/vi/DVWxQvlgRrM/default.jpg             False
# 27883  https://i.ytimg.com/vi/j1oMVG1ZMlA/default.jpg             False
# 14229  https://i.ytimg.com/vi/II-OP6vdMs8/default.jpg             False
# 31129  https://i.ytimg.com/vi/mjtn3EEG65Q/default.jpg             False
# 22272  https://i.ytimg.com/vi/CBZgoICDr6E/default.jpg             False
# 34291  https://i.ytimg.com/vi/NclJj1h_MW4/default.jpg             False
# 8514   https://i.ytimg.com/vi/pNpsjMnO7mU/default.jpg             False
# 31564  https://i.ytimg.com/vi/1x_5E3gquFo/default.jpg             False
# 4875   https://i.ytimg.com/vi/Vlv_rWiwp-0/default.jpg             False
# 16530  https://i.ytimg.com/vi/i7FgneNlM14/default.jpg             False
# 13369  https://i.ytimg.com/vi/SHI6LfICx6k/default.jpg             False
# 30760  https://i.ytimg.com/vi/xzWDIgvsFTY/default.jpg             False
# 30755  https://i.ytimg.com/vi/TvLGiAbgRc4/default.jpg             False
# 4148   https://i.ytimg.com/vi/S91qCkeiu3U/default.jpg             False
# 7326   https://i.ytimg.com/vi/WHzTLDP4o_Q/default.jpg             False
# 11537  https://i.ytimg.com/vi/-tjucPZlcgc/default.jpg             False
# 13624  https://i.ytimg.com/vi/eT9eWtb7C4c/default.jpg             False
# 14293  https://i.ytimg.com/vi/oJ_g5fUxtQo/default.jpg             False
# 178    https://i.ytimg.com/vi/S0A4hBJHND4/default.jpg             False
# 12001  https://i.ytimg.com/vi/kQQZ2hje42E/default.jpg             False
# 8310   https://i.ytimg.com/vi/d5w7iCkHvaU/default.jpg             False
# 13559  https://i.ytimg.com/vi/9Jn8TXoPQTg/default.jpg             False
# 16137  https://i.ytimg.com/vi/3QeRZj3LhS4/default.jpg             False
# 105    https://i.ytimg.com/vi/_wM_jY_rass/default.jpg              True
# 127    https://i.ytimg.com/vi/l9nGCJlDclQ/default.jpg             False
#
#       ratings_disabled video_error_or_removed  \
# 7034             False                  False
# 37098            False                  False
# 7274             False                  False
# 18842            False                  False
# 14680            False                  False
# 20791            False                  False
# 16493            False                  False
# 18004            False                  False
# 21649            False                  False
# 37097            False                  False
# 7075             False                  False
# 14402            False                  False
# 2843             False                  False
# 15554            False                  False
# 6590             False                  False
# 36562            False                  False
# 15311            False                  False
# 13558            False                  False
# 17013            False                  False
# 36191            False                  False
# 42134            False                  False
# 27883            False                  False
# 14229            False                  False
# 31129            False                  False
# 22272            False                  False
# 34291            False                  False
# 8514             False                  False
# 31564            False                  False
# 4875             False                  False
# 16530            False                  False
# 13369            False                  False
# 30760            False                  False
# 30755            False                  False
# 4148             False                  False
# 7326             False                  False
# 11537            False                  False
# 13624            False                  False
# 14293            False                  False
# 178              False                  False
# 12001            False                  False
# 8310             False                  False
# 13559            False                  False
# 16137            False                  False
# 105              False                  False
# 127              False                  False
#
#                                              description country  \
# 7034   Ajit Pai has been at the heart of the net neut...      GB
# 37098  About This Is America: Women’s EditI thought i...      GB
# 7274             December 13, 2017 | Montgomery, Alabama      GB
# 18842  Check out the official I Feel Pretty trailer s...      GB
# 14680  “Heathers,” based on the killer cult classic, ...      GB
# 20791  🏀Fergie Performs The U.S. National Anthem / 20...      GB
# 16493  HEATHERS Official Trailer (2018) Comedy TV Sho...      GB
# 18004  In the spirit of Dr. Martin Luther King, Jr., ...      GB
# 21649  It’s official! We are excited to share a sneak...      GB
# 37097  Watch the Eurovision Song Contest on the BBC. ...      GB
# 7075   Roy Moore delivers his concession speech after...      GB
# 14402  Only in theaters July 27, 2018! \n\n--\n\nhttp...      GB
# 2843   Jaime Ciero, compositor, cantautor Chileno Me ...      GB
# 15554  We are excited to share that RollerCoaster Tyc...      GB
# 6590   Keaton Jones, a Tennessee middle schooler, is ...      GB
# 36562  Amy Schumer hosts Saturday Night Live on May 1...      GB
# 15311  ► Listen LIVE: http://power1051fm.com/\n► Face...      GB
# 13558  Donate: https://bit.ly/cmussen0114\nWe live in...      GB
# 17013                                                NaN      GB
# 36191  Amy Schumer hosts Saturday Night Live on May 1...      GB
# 42134  Robert De Niro only needed two words to introd...      GB
# 27883  On March 24 at 12pm ET, watch LIVE as the stud...      GB
# 14229  Women speaking out has finally led to men spea...      GB
# 31129  At the Midwest Gaming Classic today, Billy Mit...      GB
# 22272                                                NaN      GB
# 34291  Comedian Michelle Wolf roasts Sarah Huckabee S...      GB
# 8514   Jason Whitlock joins Colin Cowherd, Kristine L...      GB
# 31564  Dwyane Wade Trash Talks Allen Iverson and Kevi...      GB
# 4875   Inspired by the Basic Instinct video from Love...      GB
# 16530  Here’s Alex Reimer on WEEI’s Mut at Night with...      GB
# 13369  Moby discusses Everything Was Beautiful and No...      GB
# 30760  Ray Borg speaks to Ariel Helwani on The MMA Ho...      GB
# 30755  Blac Chyna designs her dream house with some h...     NaN
# 4148   Paige VanZant speaks to Ariel Helwani on The M...      GB
# 7326   Woody Woodpecker\nOwn it 2/6 on DVD & Digital\...      GB
# 11537  What's stopping you this January? We've got ev...      GB
# 13624  Starring Will Arnett, Chris Ludacris Bridges, ...      GB
# 14293  Blake Griffin and Chris Paul Nearly Fight all ...      GB
# 178    Lopovi batovima demolirali vrata hrvatskom rep...      GB
# 12001  How to make a Christmas Turkey Stuffing using ...      GB
# 8310                                   December 18, 2017      GB
# 13559  Ingredients:\n \n20ml KFC Gravy\n50ml vodka (o...      GB
# 16137  One in four women face harassment in the workp...      GB
# 105                                                  NaN      GB
# 127    During the After Show, Andy Cohen asks actress...      GB
#
#                                                     tags  category_id  \
# 7034   ,'thedc','dc','washington dc','washington','th...        804.0
# 37098  ,'nicole arbour','world's sexiest comedian','f...        806.0
# 7274                                           ,'[none]'        804.0
# 18842  ,'i feel pretty','i feel pretty trailer','i fe...        201.0
# 14680  ,'paramount network','premiere','tv show','dra...        806.0
# 20791  ,'mlg highlights','mlg','basketball','highligh...        802.0
# 16493  ,'heathers','trailer','heathers trailer','movi...        202.0
# 18004  ,'built to serve','ram serve','sunday service'...        801.0
# 21649  ,'reboottgc','netflix','netflixkids','mainfram...        202.0
# 37097  ,'eurovision','2018','bbc eurovision','competi...        806.0
# 7075   ,'nbc news','breaking news','us news','politic...        102.0
# 14402  ,'teen titans movie','teen titans','will arnet...        806.0
# 2843   ,'jaime ciero','compositor','cantautor chileno...        600.0
# 15554  ,'rollercoaster tycoon','nintendo switch','rct...        803.0
# 6590   ,'video','cbs','news','keaton jones','tennesse...        102.0
# 36562  ,'snl','aidy bryant','amy schumer snl promo','...        806.0
# 15311  ,'the breakfast club','power1051','celebrity n...        806.0
# 13558  ,'chelsea manning','u.s. senate','politics','m...        804.0
# 17013  ,'kfc','kentucky fried chicken','fried chicken...        806.0
# 36191  ,'snl','amy schumer','amy schumer snl promo','...        806.0
# 42134                        ,'variety','variety studio'        806.0
# 27883                                          ,'[none]'        101.0
# 14229  ,'full frontal with samantha bee','full fronta...        804.0
# 31129                                          ,'[none]'        804.0
# 22272             ,'dota dota 2 esl one katowice vp mvp'        803.0
# 34291  ,'politics','white house','news','desk video',...        102.0
# 8514   ,'fox','fox sports','fs1','fox sports 1','coli...        802.0
# 31564  ,'nba','nba highlights','clivenbaparody','spor...        802.0
# 4875   ,'kendall jenner','kendall','loveadvent2017','...        804.0
# 16530  ,'weei','sports radio','alex reimer','mike mut...        802.0
# 13369  ,'moby','interview','everything was beautiful ...        600.0
# 30760  ,'mmafighting.com','mma','fighting','mmafighti...        802.0
# 30755                                                NaN          NaN
# 4148   ,'mmafighting.com','mma','fighting','mmafighti...        802.0
# 7326                                 ,'woody woodpecker'        201.0
# 11537   ,'fitness','active','activewear','davina mccall'          NaN
# 13624  ,'show dogs','movie','dogs','talking dogs','wi...        806.0
# 14293  ,'nba','nba fights','chris paul','blake griffi...        806.0
# 178                                            ,'[none]'        806.0
# 12001  ,'christmas','turkey','stuffing','recipe','foo...          NaN
# 8310   ,'diddy','panthers','steph curry','buy panther...        804.0
# 13559  ,'kfc','kentucky fried chicken','gravy','gravy...        806.0
# 16137  ,'harassment','sexual harassment prevention','...        806.0
# 105                                            ,'[none]'        102.0
# 127    ,'what what happens live','reality','interview...        806.0
#
#        net_dislikes
# 7034       134572.0
# 37098       58311.0
# 7274        50102.0
# 18842       16258.0
# 14680       15327.0
# 20791       14648.0
# 16493       11130.0
# 18004        5458.0
# 21649        5194.0
# 37097        5039.0
# 7075         4129.0
# 14402        3700.0
# 2843         2518.0
# 15554        2370.0
# 6590         2202.0
# 36562        1987.0
# 15311        1454.0
# 13558        1410.0
# 17013        1358.0
# 36191         943.0
# 42134         938.0
# 27883         932.0
# 14229         739.0
# 31129         572.0
# 22272         456.0
# 34291         441.0
# 8514          360.0
# 31564         313.0
# 4875          298.0
# 16530         140.0
# 13369         127.0
# 30760         118.0
# 30755         113.0
# 4148           71.0
# 7326           43.0
# 11537          38.0
# 13624          32.0
# 14293          29.0
# 178            25.0
# 12001          21.0
# 8310           19.0
# 13559          13.0
# 16137          12.0
# 105             4.0
# 127             3.0

# %% [markdown]
# *The table above shows videos in GB that had their **dislikes** more than their **likes** when they first appeared on the particular region's trending list - in total **45** videos.*

# %% [markdown]
# ## 3rd: The most common words in titles (GB)

# %%
new_gb_df = gb[gb['title'].notnull()]

# %%
title_words_gb = list(new_gb_df['title'].apply(lambda x: x.split()))
title_words_gb = [x for y in title_words_gb for x in y]
Counter(title_words_gb).most_common(30)
# Out:
# [('-', 17845),
#  ('|', 8728),
#  ('The', 6012),
#  ('Video)', 3757),
#  ('(Official', 3526),
#  ('&', 3075),
#  ('the', 2773),
#  ('Trailer', 2394),
#  ('ft.', 2238),
#  ('of', 2115),
#  ('Official', 2104),
#  ('and', 1817),
#  ('in', 1682),
#  ('A', 1682),
#  ('Music', 1659),
#  ('to', 1512),
#  ('on', 1399),
#  ('2018', 1351),
#  ('I', 1246),
#  ('with', 1245),
#  ('a', 1179),
#  ('Me', 1092),
#  ('My', 1000),
#  ('Star', 958),
#  ('[Official', 940),
#  ('Video]', 917),
#  ('In', 847),
#  ('To', 807),
#  ('You', 807),
#  ('Last', 795)]

# %% [markdown]
# *In GB the most common words in titles is **"The", "Video"** and **"(Official"** - they appeared **6012**, **3757** and **3526** times respectively. Only symbols appeared more often than these words: "-" and "|" occured the most: **17845** and **8728** times respectively.*

# %% [markdown]
# ## 4th: What are the most common tags in each of the categories? (GB)

# %% [markdown]
# *First, check what's the most common tags in the hole dataset (GB).*

# %%
new_gb_df_tags = gb[gb['tags'].notnull()]

# %%
popular_tags_gb = list(new_gb_df_tags['tags'].apply(lambda x: x.split()))
popular_tags_gb = [x for y in popular_tags_gb for x in y]
Counter(popular_tags_gb).most_common(30)
# Out:
# [('the', 9978),
#  ('of', 4893),
#  ('and', 3862),
#  ('to', 3719),
#  ('me', 2768),
#  ('a', 2634),
#  ('in', 2559),
#  ('music', 2443),
#  ('new', 2437),
#  ('last', 2243),
#  ('&', 2235),
#  ('official', 2184),
#  ('wars', 2135),
#  ('you', 2104),
#  (",'[none]'", 2003),
#  ('for', 1961),
#  ('on', 1861),
#  ('my', 1695),
#  ('with', 1495),
#  (",'the", 1464),
#  ('vs', 1423),
#  ('i', 1421),
#  ('is', 1407),
#  ('ft.', 1364),
#  ('voice', 1239),
#  ('-', 1221),
#  ('star', 1208),
#  ('late', 1185),
#  ('it', 1047),
#  ('jedi', 981)]

# %% [markdown]
# ## 5th: What are the relationship between the number of tags and the number of views? Does this relationship appears in all countries?

# %%
gb['num_tags_gb'] = gb['tags'].astype(str).apply(lambda x: len(x.split(',')) if x != '[none]' else 0)

# %%
ax = gb.plot(kind='scatter', x='num_tags_gb', y='views', figsize=(14,8))
plot_configurations(ax, xlbl='Number of tags', ylbl='Number of views')

# %% [markdown]
# ### Relationship between description length and number of views

# %%
fig, ax_gb = plt.subplots(figsize=(14,8))
sns.scatterplot(x=gb['description'].str.len(), y=gb['views'])
plot_configurations(ax_gb, xlbl='Description length', ylbl='Number of views')

# %% [markdown]
# *The last Scatter Plot above displays the biggest relationship changes between number of views and lenght of description, compaired to last 2 datasets. Here in GB there is significantly more those videos with a long description, if we compaire with US and CAN.*

# %% [markdown]
# ## Predict the category of video from tags.

# %% [markdown]
# ## Analysis Results

# %% [markdown]
# ### Insight Nr.1

# %% [markdown]
# *In all 3 regions I saw very similar picture in terms of the **time of the day** when the most trending videos were published. The most trending videos in these regions was published in the afternoon, gaining rapid increase at 1:00 p.m and reaching the maximum at **4 p.m.,** while early morning hours (6:00 a.m. - 9.00 a.m) showed the lowest publishing activity, which can be explained by the absence of people at this time meaning this is the time when you dont want to publish a video if you want it to go viral.*

# %% [markdown]
# ### Insight Nr.2

# %% [markdown]
# *There were also similarities in days that were the most common for the trending videos to be published in. As it was expected, the most popular was working days with Friday being the most active and Monday - the least active. On holidays frequency of publicity decreased, but not to the same extent in all regions.*

# %% [markdown]
# ### Insight Nr.3

# %% [markdown]
# However, in USA, Canada and Great Britain there are differences in the popularity of channels. In Canada the most popular channels are **news-based-channels**, like SET India that is entertainment pay television channel, followed by MSNBC (news-based TV channel) and so on. The only **talk-show-based** channel in TOP 10 list is The Late Show with Stephen Colbert.

# %% [markdown]
# *In the **United States** the most popular was sport channels like "ESPN" and "NBA", as well as the same talk-shows and news site "Vox".*

# %% [markdown]
# *We can conclude that in Great Britain is more similar to United States, GB is dominated with **talk-show** channels like "The Tonight Show Starring Jimmy Fallon", "Jimmy Kimmel Live", "The EllenShow" and others. TOP 10 also entered by WWE that offers original shows and exclusives.*

# %% [markdown]
# ### Business Team Question 1:

# %% [markdown]
# *Are there any clear differences between trending videos depending on the region?*

# %% [markdown]
# *Yes, according to my analysis there are clear differences between trending videos depending on the region. For example, in Canada's trending list there was almost **3** times more political videos than in Great Britains. At the same time in Great Britain there was almost twice as much Music videos than in USA, and almost **3** times as much than in Canada. There were also a clear difference in terms of Educational videos, in US trending list the educational videos appeared **4** times more often than in Great Britain. No significant differences were observed in the other categories.*

# %% [markdown]
# * **USA -->** Entertainment (50,58%), Music (17,04%), Education (10,51%), Politics (6,60%), Cinema (6,32%), DIY&Beauty (5,34%), Animals (2,37%) and Travel&Events (0,96%)*

# %% [markdown]
# * **CANADA** --> Entertainment (64,69%), Music (9,71%), Education (5,52%), Politics (10,06%), Cinema (5,41%), DIY&Beauty (2,63%), Animals (0,95%) and Travel&Events (1,02%)*

# %% [markdown]
# * **GREAT BRITAIN** --> Entertainment (45,93%), Music (36,80%), Education (2,58%), Politics (3,53%), Cinema (6,80%), DIY&Beauty (2,78%), Animals (1,32%) and Travel&Events (0,26%)*

# %% [markdown]
# ### Business Team Question 2:

# %% [markdown]
# *Which video remained the most on the trending videos list?*

# %% [markdown]
# *Overall in all 3 regions the video that remained the most on the trending video list was called **"Maroon 5 - Wait",** it appeared on the list 40 times - it was achieved in Great Britain.*

# %% [markdown]
# *If we are taking a closer look in other regions... in USA video that remained the most on the trending videos list is called **"WE MADE OUR MOM CRY...HER DREAM CAME TRUE!"** (30 times). In Canada the 1st place for the video that remained the most on trending video list occupies 2 songs - called **"Drake - God's Plan (Official Audio)",** and **"Most Popular Violin Covers of Popular Songs 2018 || Best Instrumental Violin Covers 2018",** each of them appeared on the list **15** times.*

# %% [markdown]
# ### Business Team Question 3:

# %% [markdown]
# *Which video category has the largest number of trending videos? Does the category give any advantage in order to become trending?*

# %% [markdown]
# *In all 3 regions the largest number of trending videos had video category **Entertainment.** This is a perfect proof that shows the category of video definitely gives advantage in order to become trending. Since most people use YouTube "to shorten the time" it is no suprise that the most common video category was Entertainment.*

# %% [markdown]
# ### Business Team Question 4:

# %% [markdown]
# *How are views, likes and dislikes, title length, and other attributes correlated with (relate to) each other? Are they connected in any way?*

# %% [markdown]
# *I played a little bit with simple correlation functions, where I saw this correlation - comment count is positevely related with views, likes and dislikes. That means that people who react with a like or dislike are also more likely to leave a comment after watching the video.*

# %% [markdown]
# ### Business Team Question 5:

# %% [markdown]
# *If Nordigen would upload a video, what words in the title (or description) or tags would you recommend to use? (In hopes to make the video trending)*

# %% [markdown]
# *The words I would recomment to use in hopes to make the video trending partly would depend on type of content Nordigen would publish. I would definitely not recommend to use the most popular keywords in the title, description or tags, because those are extremely busy keywords, hence it is only recomemended to use if you have a massive following, otherwise it's non effective way to make video trending. I would recommend to use keywords that are related to the company's niche (baltic banking, open-banking, etc.). I do have to mention that I would recommend to make content that is a mix of 2 different topics - Nordigen related information with a touch of entertainment.*

# %% [markdown]
# # Additional questions:

# %% [markdown]
# #### 1st: How many comments a video has when first appearing on the trending list?

# %% [markdown]
# #### 2nd: How many videos in each country that had their Dislikes more than their Likes when first appeared on the trending list?

# %% [markdown]
# *In US there was **101** videos that had more dislikes than likes, in CAN **113** and in GB **45** videos.*

# %% [markdown]
# #### 3rd: What are the most common words in titles?

# %% [markdown]
# *The most common words in titles in all 3 countries is **"The", "the", "a", "Video", "(Official", "Episode"**. Only symbols appeared more often than these words: **"-"** and **"|"**. Below is a more detailed description.*

# %% [markdown]
# *In USA the most common words in titles is "The", "the" and "a" - they appeared 5762, 3949 and 2858 times respectively. Only symbols appeared more often than these words: "-" and "|" occured the most: 11452 and 10660 times respectively.*

# %% [markdown]
# *In GB the most common words in titles is "The", "Video" and "(Official" - they appeared 6012, 3757 and 3526 times respectively. Only symbols appeared more often than these words: "-" and "|" occured the most: 17845 and 8728 times respectively.*

# %% [markdown]
# *In CA the most common words in titles is "The", "the" and "Episode" - they appeared 5167, 2617 and 2298 times respectively. Only symbols appeared more often than these words: "-" and "|" occured the most: 12537 and 12519 times respectively.*

# %% [markdown]
# ## 4th: What are the most common tags in each of the categories?

# %% [markdown]
# ### 5th: What are the relationship between the number of tags and the number of views? Does this relationship appears in all countries?

# %% [markdown]
# *By comparing all regions there is a relationship: the biggest part of videos has no more than **40** tags. After **40** tags the number of videos falls significantly in all regions. This relationship does appear in all countries. It is worth mentioning that in US and GB there are no videos with more than **70** tags, but in CAN there are videos with more than **120** tags.*

# %% [markdown]
# *Additionaly, I managed to find out the relationship between **description length and number of views.** By taking all 3 graphs side by side, you can see that in US the number of videos with long description is significantly lower than in Canada. It's hard to tell exactly, but it seems that in Canada, the number of videos with at least 3000 character long description could be even **2.5** times higher than in US. In contrast, distribution of videos with at least 3000 characters in description is much more irregular in GB, overall the number of these videos is similar to that in US.*

# %% [markdown]
# *You could say that in CAN the distribution of videos with long description is the most extreme, it's the most flattened out, compared to other regions.*

# %% [markdown]
# ### Questions that I am interested in (1):

# %% [markdown]
# *Which videos had the most views in each region (USA, Canada, GB)?*

# %% [markdown]
# *In Great Britain video with the MOST views is called "Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic..." from channel "NickyJamTV" which had accumulated more than **424 million** views.*

# %% [markdown]
# *In Canada Video with the MOST views is called "YouTube Rewind: The Shape of 2017 | #YouTubeRe..." from channel "YouTube Spotlight" which had accumulated more than **137 million** views.*

# %% [markdown]
# *Video with the *MOST** views is called "Childish Gambino - This Is America (Official Video)" from channel "ChildsihGambinoVEVO" which had accumulated more than **225 million** views.*

# %% [markdown]
# ### Questions that I am interested in (2):

# %% [markdown]
# *How much of trending videos had their comments and ratings option turned off?*

# %% [markdown]
# *In all 3 regions the number of trending videos with turned off comment and rating option was extremly tiny - not even a 2%, which tells me that you better allow people to comment and rate your video if you want the best adds to get your video go viral.*

# %% [markdown]
# ### The problems encountered

# %% [markdown]
# *Looks like I have data formatting issues or something along these lines because while performing analysis, there was a times when I saw unlogical results. For example, identifying the most popular channels - the results showed channels like "806" which are not legit channel. Those looks like a category codes that somehow has been picked up and shown in results.*

# %% [markdown]
# *If I had more time I would like to go into this problem and understand why it happened, which I am about to do soon, because, as we all know, going through confusion is the best way to strengthen knowledge.*

# %% [markdown]
# ## The End!
